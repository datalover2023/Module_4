# %% [raw]
# Libraries

# %%
import os
import glob
import pandas as pd
import numpy as np

from openpyxl import load_workbook # necesserry library


# utility functions for cells locations
# !pip install xlsxwriter
import xlsxwriter
from xlsxwriter.utility import xl_rowcol_to_cell
from xlsxwriter.utility import xl_col_to_name
from xlsxwriter.utility import xl_range, xl_range_abs
from openpyxl.utils import get_column_letter, column_index_from_string

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# set visible all columns
pd.set_option('display.max_columns', None)

# %%
# assing current working directory (`cwd`)
cwd = os.getcwd()
cwd
# Out:
# '/home/e57658/workspace/Excel_Automation_Python/Module_4'

# %%
# List all files and directories in current directory
os.listdir('.')
# Out:
# ['Budget_UseCase.ipynb',
#  '.ipynb_checkpoints',
#  'Budget_UseCase_Integral.ipynb',
#  'Budget_processed.xlsx',
#  'Formating_Budget_UseCase.ipynb',
#  'Formating_Budget.xlsx',
#  'Budget_raw.xlsx',
#  'Budget_template.xlsx',
#  'Budget_processed_final.xlsx',
#  'images',
#  'Next_Month.xlsx',
#  'new.xlsx',
#  'new_transp.xlsx',
#  'Join_Merge_Concat.ipynb',
#  'Budget_raw_update.xlsx',
#  'Budget_UseCase_Update_NextMonth.ipynb']

# %% [markdown]
# # DF, read Excel

# %%
# read excel and put it in a dataframe

filename='Budget_raw.xlsx'
df = pd.read_excel(filename, index_col=None, header=0)
df = pd.DataFrame(df)
# df = df.set_index(['Region', 'Business', 'Department'])

print('df dimensions: ', df.shape)
print('df lengh: ', len(df))
print('df columns: ', df.columns)
# display first 8 rows
df.head(8)
# Out:
# df dimensions:  (1937, 15)
# df lengh:  1937
# df columns:  Index(['Business', 'Department', 'Region', 'Jan Income', 'Feb Income',
#        'Mar Income', 'Apr Income', 'May Income', 'Jun Income',
#        'Jan Expenditure', 'Feb Expenditure', 'Mar Expenditure',
#        'Apr Expenditure', 'May Expenditure', 'Jun Expenditure'],
#       dtype='object')
#   Business Department Region  Jan Income  Feb Income  Mar Income  Apr Income  \
# 0    B2C_1      Loans     AT     5924.95     4680.71     7406.19     7169.19
# 1    B2C_1      Loans     AT     5924.95     7346.94     6872.94     4739.96
# 2    B2C_1      Loans     AT     5924.95     7406.19     6043.45     6161.95
# 3    B2C_1   Services     AT     5924.95     5865.70     7406.19     4858.46
# 4    B2C_1      Loans     AT     5924.95     6280.45     6102.70     6339.70
# 5    B2C_1      Loans     AT     5867.90     7334.88     6102.62     4987.72
# 6    B2C_1      Loans     AT     5824.70     6814.90     6989.64     4543.27
# 7    B2C_1      Loans     AT     5924.95     5391.70     4976.96     7346.94
#
#    May Income  Jun Income  Jan Expenditure  Feb Expenditure  Mar Expenditure  \
# 0     7406.19     5213.96          5178.13          3883.60          3534.08
# 1     6280.45     6576.69          3913.87          3835.59          4410.93
# 2     6161.95     5924.95          4386.71          3377.77          3411.55
# 3     5984.20     7169.19          4840.73          4743.92          5692.70
# 4     5865.70     6458.20          5875.00          5698.75          5983.69
# 5     6043.94     6396.01          2229.34          2162.46          2551.70
# 6     6465.42     5649.96          2199.00          1737.21          2015.16
# 7     6102.70     5806.45          3924.12          3767.16          4068.53
#
#    Apr Expenditure  May Expenditure  Jun Expenditure
# 0          4240.90          3731.99          4217.15
# 1          4058.06          4220.38          5064.46
# 2          3206.86          3399.27          3229.31
# 3          5123.43          4867.26          5500.00
# 4          6701.73          7505.94          8481.71
# 5          2908.94          3112.57          3237.07
# 6          2115.92          1883.17          1977.33
# 7          3987.16          4505.49          3964.83

# %%
# check data dypes for each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1937 entries, 0 to 1936
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Business         1937 non-null   object
#  1   Department       1937 non-null   object
#  2   Region           1937 non-null   object
#  3   Jan Income       1937 non-null   float64
#  4   Feb Income       1937 non-null   float64
#  5   Mar Income       1937 non-null   float64
#  6   Apr Income       1937 non-null   float64
#  7   May Income       1937 non-null   float64
#  8   Jun Income       1937 non-null   float64
#  9   Jan Expenditure  1937 non-null   float64
#  10  Feb Expenditure  1937 non-null   float64
#  11  Mar Expenditure  1937 non-null   float64
#  12  Apr Expenditure  1937 non-null   float64
#  13  May Expenditure  1937 non-null   float64
#  14  Jun Expenditure  1937 non-null   float64
# dtypes: float64(12), object(3)
# memory usage: 227.1+ KB

# %%
# read excel and put it in a dataframe

next_file='Next_Month.xlsx'
df_next = pd.read_excel(next_file, index_col=None, header=0)
df_next = pd.DataFrame(df_next)
#df_next = df_next.sort_values(by=['Region', 'Business', 'Department'], ascending=True)
df_next.reset_index(drop = True,  inplace = True)
df_next = df_next.set_index(['Region', 'Business', 'Department'])

print('df dimensions: ', df_next.shape)
print('df lengh: ', len(df_next))
print('df columns: ', df_next.columns)
# display first 8 rows
df_next.head(8)
# Out:
# df dimensions:  (1937, 2)
# df lengh:  1937
# df columns:  Index(['July Income', 'July Expenditure'], dtype='object')
#                             July Income  July Expenditure
# Region Business Department
# AT     B2C_1    Loans       5668.401744       1344.650764
#                 Loans       4171.916517       3681.710708
#                 Loans       1330.935798        911.586699
#                 Services    4416.591440       1657.135837
#                 Loans       4136.017540       5330.310997
#                 Loans       2485.707305       2203.774721
#                 Loans       3315.317734       1460.735427
#                 Loans       4750.327765        744.838461

# %%
df_t = df.T
print(df_t.shape)
df_t.head()
# Out:
# (15, 1937)
#                0        1        2         3        4        5       6     \
# Business      B2C_1    B2C_1    B2C_1     B2C_1    B2C_1    B2C_1   B2C_1
# Department    Loans    Loans    Loans  Services    Loans    Loans   Loans
# Region           AT       AT       AT        AT       AT       AT      AT
# Jan Income  5924.95  5924.95  5924.95   5924.95  5924.95   5867.9  5824.7
# Feb Income  4680.71  7346.94  7406.19    5865.7  6280.45  7334.88  6814.9
#
#                7        8           9            10           11       12    \
# Business      B2C_1    B2C_1         B2B        B2C_1        B2C_1    B2C_1
# Department    Loans    Loans  Assistance  Maintenance  Maintenance    Loans
# Region           AT       AT          AT           AT           AT       AT
# Jan Income  5924.95  5924.95      663.75      5924.95      5924.95  5924.95
# Feb Income   5391.7  7346.94      829.69      5213.96      5806.45  5036.21
#
#                   13           14          15      16       17           18    \
# Business         Fleet        B2C_1       B2C_1   B2C_1    B2C_1        B2C_1
# Department  Assistance  Maintenance  Assistance   Loans    Loans  Maintenance
# Region              AT           AT          AT      AT       AT           AT
# Jan Income       893.9      5924.95     1092.25  4900.7   5499.8      5006.85
# Feb Income     1010.11      4443.71     1092.25  4900.7  5224.81      5207.12
#
#                19      20           21       22          23          24    \
# Business      B2C_1   B2C_2        B2C_1    B2C_1         B2B       B2C_1
# Department    Loans    Fees  Maintenance    Loans  Assistance  Assistance
# Region           AT      AT           AT       AT          AT          AT
# Jan Income   4698.0  4627.0      4928.85  4294.15      1526.4     1596.45
# Feb Income  4979.88  5089.7      4337.39  5024.16     1556.93     1612.41
#
#                25          26       27           28       29          30    \
# Business      B2C_2       B2C_1    B2C_1        B2C_2    B2C_2       B2C_1
# Department     Fees  Assistance    Loans         Fees     Fees  Assistance
# Region           AT          AT       AT           AT       AT          AT
# Jan Income  4881.02      1695.6  4640.95  4101.557692  3667.01     1906.25
# Feb Income  3856.01      1695.6  3944.81      4593.74  4363.74     1906.25
#
#                31        32           33          34          35       36    \
# Business      B2C_2     B2C_2        B2C_1         B2B       B2C_1    B2C_1
# Department     Fees      Fees  Maintenance  Assistance  Assistance    Loans
# Region           AT        AT           AT          AT          AT       AT
# Jan Income  3653.11  3737.075       3732.5     2387.16     2284.65  3524.75
# Feb Income  3616.58   3363.37       3732.5     2076.83     2284.65   3560.0
#
#                37       38           39           40           41    \
# Business      B2C_1    B2C_2        B2C_1        B2C_1        B2C_1
# Department    Loans     Fees  Maintenance  Maintenance  Maintenance
# Region           AT       AT           AT           AT           AT
# Jan Income  3499.65  3304.51      3394.25       3302.4      3273.15
# Feb Income  3499.65  3502.78      3428.19      3335.42      3273.15
#
#                   42       43          44          45           46    \
# Business         B2C_1    B2C_2       B2C_1       B2C_1        B2C_1
# Department  Assistance     Fees  Assistance  Assistance  Maintenance
# Region              AT       AT          AT          AT           AT
# Jan Income     2901.45  3220.16     2999.65      3016.1     2822.825
# Feb Income     2901.45  2994.75     2999.65      3016.1      2822.83
#
#                    47          48       49        50       51           52    \
# Business          B2C_2       B2C_1    B2C_2     B2C_2    B2C_2        B2C_1
# Department  Maintenance  Assistance     Fees  Services     Fees        Loans
# Region               AT          AT       AT        AT       AT           AT
# Jan Income       2661.2     3258.71  2722.76    2239.5  2554.52  2406.652564
# Feb Income      2315.24     3258.71  2477.71   2776.98  2477.88      2406.65
#
#                   53       54       55           56           57       58    \
# Business         B2C_1      B2B    B2C_2        B2C_1          B2B    B2C_1
# Department  Assistance    Loans     Fees  Maintenance  Maintenance    Loans
# Region              AT       AT       AT           AT           AT       AT
# Jan Income     3497.65  2093.15  2292.96      2169.35      2346.85  2114.35
# Feb Income     3497.65  2511.78  2453.47      2169.35      1947.89  2114.35
#
#                    59       60           61           62           63    \
# Business          B2C_2    B2C_2        B2C_1          B2B        B2C_1
# Department  Maintenance    Loans  Maintenance  Maintenance  Maintenance
# Region               AT       AT           AT           AT           AT
# Jan Income      2051.15  2057.85      2026.75       1975.0      2009.05
# Feb Income      2338.31  2304.79      2026.75       2291.0      2029.14
#
#               64       65        66       67       68           69    \
# Business     B2C_1    B2C_2     Fleet    B2C_1      B2B        B2C_1
# Department   Loans     Fees  Services    Loans    Loans  Maintenance
# Region          AT       AT        AT       AT       AT           AT
# Jan Income  1956.9  2011.32    1902.5  1882.25   1991.5       1803.9
# Feb Income  1956.9   1528.6   2016.65  1901.07  1573.29       1803.9
#
#                    70           71           72           73       74    \
# Business          B2C_2        B2C_1        B2C_2          B2B    B2C_2
# Department  Maintenance  Maintenance  Maintenance  Maintenance     Fees
# Region               AT           AT           AT           AT       AT
# Jan Income     1818.175       1732.4    1573.6725       1553.9  1662.72
# Feb Income      2072.72       1732.4      1967.09       1631.6   1712.6
#
#                75           76       77       78       79        80    \
# Business      B2C_2          B2B    B2C_2    B2C_2    B2C_2     B2C_2
# Department     Fees  Maintenance     Fees     Fees     Fees  Services
# Region           AT           AT       AT       AT       AT        AT
# Jan Income  1448.56      1476.85  1443.85  1292.21  1245.01   1265.76
# Feb Income  1549.96      1698.38  1516.04  1563.57  1319.71   1113.87
#
#                    81           82       83       84      85           86    \
# Business          B2C_2        B2C_2    B2C_2    B2C_2   B2C_2        B2C_1
# Department  Maintenance  Maintenance     Fees     Fees    Fees   Assistance
# Region               AT           AT       AT       AT      AT           AT
# Jan Income       1376.9     1252.125  1235.31  1074.97  1122.4  5874.566667
# Feb Income      1473.28      1515.07   963.54  1332.96  954.04      4699.65
#
#                   87       88       89       90        91      92        93    \
# Business         B2C_1    B2C_2    B2C_2    B2C_2     B2C_2   B2C_2     Fleet
# Department  Assistance     Fees     Fees     Fees  Services    Fees  Services
# Region              AT       AT       AT       AT        AT      AT        AT
# Jan Income     5450.55  1111.92  1154.06   928.56    852.85  779.41    735.86
# Feb Income     6486.15   978.49   923.25  1151.41    946.66   654.7    772.65
#
#              94        95      96      97          98           99      100   \
# Business    B2C_2     Fleet   B2C_2   B2C_2       B2C_1        B2C_2   B2C_2
# Department  Loans  Services    Fees    Fees  Assistance  Maintenance    Fees
# Region         AT        AT      AT      AT          AT           AT      AT
# Jan Income  694.0    705.96  747.46  562.31     5924.95        532.5  373.11
# Feb Income  798.1    614.19  739.99  607.29     5687.95       415.35   444.0
#
#              101       102          103       104       105      106   \
# Business    Fleet     Fleet        B2C_1     Fleet     Fleet      B2B
# Department   Fees  Services  Maintenance  Services  Services    Loans
# Region         AT        AT           AT        AT        AT       BE
# Jan Income  355.0     355.0      340.825     355.0     260.0  5924.95
# Feb Income  433.1    436.65       344.23     340.8     236.6  7169.19
#
#                107      108         109      110      111      112      113   \
# Business      B2C_1    B2C_1       B2C_2    B2C_1    B2C_1      B2B    B2C_1
# Department    Loans    Loans  Assistance    Loans    Loans    Loans    Loans
# Region           BE       BE          BE       BE       BE       BE       BE
# Jan Income   5858.6  5924.95      19.875  5924.95  5924.95  5924.95  5924.95
# Feb Income  6210.12  6991.44       19.28  6635.94  5687.95   6221.2  5569.45
#
#                114      115      116          117      118      119      120   \
# Business      B2C_1    B2C_1    B2C_1        B2C_1      B2B    B2C_1    B2C_1
# Department    Loans    Loans    Loans  Maintenance    Loans    Loans    Loans
# Region           BE       BE       BE           BE       BE       BE       BE
# Jan Income   5695.8  5924.95  5924.95      5924.95  5881.86  5924.95  5924.95
# Feb Income  6208.42   6102.7   5747.2      6576.69  5881.86  5273.21  7406.19
#
#                121         122      123      124          125      126   \
# Business      B2C_1       B2C_1    B2C_2    B2C_1        B2C_1    B2C_1
# Department    Loans  Assistance     Fees    Loans  Maintenance    Loans
# Region           BE          BE       BE       BE           BE       BE
# Jan Income  5924.95     583.125  5924.95  5924.95       5651.3  5924.95
# Feb Income  6517.45      588.96  5213.96   6102.7      5820.84  4502.96
#
#                   127          128      129         130         131      132   \
# Business         B2C_1        B2C_1    B2C_1       B2C_1       B2C_1    B2C_1
# Department  Assistance  Maintenance    Loans  Assistance  Assistance    Loans
# Region              BE           BE       BE          BE          BE       BE
# Jan Income       923.8      5225.25  5765.35     1056.25      1061.5   5547.7
# Feb Income       923.8      6322.55  5304.12     1056.25     1072.12  5048.41
#
#                133      134        135      136      137          138   \
# Business      B2C_1    B2C_1        B2B    B2C_2    B2C_1        B2C_1
# Department    Loans    Loans      Loans    Loans    Loans  Maintenance
# Region           BE       BE         BE       BE       BE           BE
# Jan Income  5924.95  5924.95  5596.9625  5652.76  4682.05      5384.35
# Feb Income  4976.96  6872.94    5429.05  5596.23  5150.26      4738.23
#
#                   139         140      141      142          143         144   \
# Business         B2C_2       B2C_2    B2C_1    B2C_1        B2C_1       B2C_1
# Department  Assistance  Assistance    Loans    Loans  Maintenance  Assistance
# Region              BE          BE       BE       BE           BE          BE
# Jan Income     1195.56      1360.6  5125.96  5421.91       5565.7     1502.46
# Feb Income     1470.54     1523.87  4459.59  5476.13      6233.58     1517.48
#
#                145      146         147      148      149       150   \
# Business      B2C_2    B2C_1       B2C_1    B2C_1    B2C_2       B2B
# Department     Fees    Loans  Assistance    Loans     Fees  Services
# Region           BE       BE          BE       BE       BE        BE
# Jan Income  4899.86  4805.35      1507.3  4807.45  4150.92   4568.65
# Feb Income  4507.87  5430.05     1522.37  5913.16  5105.63   4842.77
#
#                    151          152      153        154          155   \
# Business          B2C_1        B2C_1    B2C_1      B2C_1        B2C_1
# Department  Maintenance  Maintenance    Loans      Loans  Maintenance
# Region               BE           BE       BE         BE           BE
# Jan Income       4176.3  5218.766667  4272.25  4625.2625  4098.103846
# Feb Income      3716.91      3914.07  3930.47     3607.7      4712.82
#
#                156      157      158      159      160          161   \
# Business      B2C_1      B2B    B2C_2    B2C_2    B2C_1        B2C_1
# Department    Loans    Loans    Loans     Fees    Loans  Maintenance
# Region           BE       BE       BE       BE       BE           BE
# Jan Income  4212.95  4187.25   4172.0  4394.76   4032.6      4225.25
# Feb Income  4676.37  4438.49  5048.12  3955.28  4435.86      4225.25
#
#                    162          163          164      165         166   \
# Business          B2C_1        B2C_1        B2C_1    B2C_1         B2B
# Department  Maintenance  Maintenance  Maintenance    Loans  Assistance
# Region               BE           BE           BE       BE          BE
# Jan Income       3986.3      3907.75      3748.15  3589.35      2720.6
# Feb Income       3986.3      3946.83      3748.15  3589.35     2339.72
#
#                167         168      169        170       171        172   \
# Business      B2C_2       B2C_1    B2C_2      B2C_2       B2B      B2C_1
# Department     Fees  Assistance     Fees       Fees  Services      Loans
# Region           BE          BE       BE         BE        BE         BE
# Jan Income   3564.6     2412.95  3262.51  3856.8575    3179.2  3158.1375
# Feb Income  3386.37     2412.95  3621.39    3046.92    2765.9    3158.14
#
#                    173          174          175     176     177        178   \
# Business            B2B        B2C_1        B2C_1   B2C_1   B2C_1      B2C_2
# Department  Maintenance  Maintenance  Maintenance   Loans   Loans       Fees
# Region               BE           BE           BE      BE      BE         BE
# Jan Income      3281.35       3104.7      3076.35  3077.2  3016.2  3244.7575
# Feb Income      3773.55       3104.7      3107.11  3077.2  3016.2    2920.28
#
#                179          180       181          182          183   \
# Business      B2C_2          B2B     B2C_2          B2B        B2C_1
# Department     Fees  Maintenance      Fees  Maintenance  Maintenance
# Region           BE           BE        BE           BE           BE
# Jan Income  2869.25      3141.57  2965.845      2807.55       2903.7
# Feb Income  3127.48      2764.58   2254.04      3397.14      2932.74
#
#                  184          185          186        187       188   \
# Business        B2C_2          B2B        B2C_1      B2C_2     B2C_2
# Department       Fees  Maintenance  Maintenance       Fees      Fees
# Region             BE           BE           BE         BE        BE
# Jan Income  2986.4625      2903.65      2803.75  2769.3075  2961.735
# Feb Income    3016.33      3106.91      2803.75    3406.25   2517.47
#
#                    189      190      191       192      193       194   \
# Business          B2C_1    B2C_1    B2C_2     B2C_2    B2C_1     B2C_2
# Department        Loans    Loans     Fees     Loans    Loans      Fees
# Region               BE       BE       BE        BE       BE        BE
# Jan Income  2742.307692  2711.76   2937.8  2807.375   2545.6  2673.035
# Feb Income      2742.31  2711.76  2262.11   2835.45  2571.06    2379.0
#
#                   195        196         197      198      199      200   \
# Business         B2C_1      B2C_2         B2B    B2C_2    B2C_2    B2C_2
# Department  Assistance       Fees  Assistance     Fees     Fees     Fees
# Region              BE         BE          BE       BE       BE       BE
# Jan Income      3308.5  2480.7325      3321.5  2445.56  2324.02  2435.85
# Feb Income     3341.59     2356.7     2790.06  2494.47  2207.82  2046.11
#
#                201      202      203          204        205      206   \
# Business      B2C_2    B2C_2    B2C_2        B2C_1      B2C_2    B2C_2
# Department    Loans     Fees     Fees  Maintenance       Fees     Fees
# Region           BE       BE       BE           BE         BE       BE
# Jan Income  2284.81  2387.26  2200.86       2175.0  2331.5975  2255.35
# Feb Income  2650.38  2625.99  1694.66      2196.75    1888.59  1714.07
#
#                 207     208          209       210      211          212   \
# Business       B2C_2   B2C_1        B2C_1       B2B    B2C_2        B2C_1
# Department  Services   Loans  Maintenance     Loans     Fees  Maintenance
# Region            BE      BE           BE        BE       BE           BE
# Jan Income   2211.55  2030.0    2028.5375  2042.375  1924.62       1897.5
# Feb Income   2476.94  2030.0      2048.82   2307.88  2405.78      1916.48
#
#                213         214       215      216     217         218   \
# Business      B2C_2       B2C_2     B2C_2    B2C_2   B2C_1       B2C_1
# Department     Fees  Assistance  Services     Fees   Loans  Assistance
# Region           BE          BE        BE       BE      BE          BE
# Jan Income   1803.0   4076.7375    1769.2  1729.82  1700.5      4211.9
# Feb Income  1514.52      3872.9   1963.81  2162.28  1700.5     4590.97
#
#                 219      220      221      222      223      224      225   \
# Business       B2C_2    B2C_2    B2C_2    B2C_2    B2C_2    B2C_2    B2C_2
# Department      Fees     Fees     Fees     Fees     Fees     Fees     Fees
# Region            BE       BE       BE       BE       BE       BE       BE
# Jan Income  1621.995  1784.11  1751.17  1501.31  1550.05  1464.65  1465.72
# Feb Income   1816.63   1605.7  1418.45  1561.36  1689.55   1259.6  1817.49
#
#                   226      227      228        229      230        231   \
# Business         B2C_1    B2C_2    B2C_2      B2C_2    B2C_1      B2C_2
# Department  Assistance     Fees     Fees       Fees    Loans       Fees
# Region              BE       BE       BE         BE       BE         BE
# Jan Income      4767.8  1438.21  1400.15  1380.4825  1227.15  1119.4975
# Feb Income     4910.83  1078.66  1526.16    1173.41  1239.42    1052.33
#
#                    232      233          234       235          236      237   \
# Business          B2C_2    B2C_2        B2C_1     B2C_1        B2C_1    B2C_2
# Department  Maintenance     Fees  Maintenance  Services  Maintenance     Fees
# Region               BE       BE           BE        BE           BE       BE
# Jan Income      1281.76  1255.21      1145.15   1145.85       1121.6  1172.91
# Feb Income      1320.21   991.62       1156.6   1145.85       1121.6  1055.62
#
#                    238          239          240      241         242   \
# Business          Fleet        B2C_2        B2C_1    B2C_2       B2C_1
# Department  Maintenance  Maintenance  Maintenance     Fees  Assistance
# Region               BE           BE           BE       BE          BE
# Jan Income      1062.15       1070.0      1088.75  1091.25     5924.95
# Feb Income        987.8        952.3      1099.64   949.39     6576.69
#
#                 243      244      245      246      247     248       249   \
# Business       B2C_2    B2C_2    B2C_2    B2C_2    B2C_2   B2C_2     B2C_2
# Department  Services     Fees     Fees     Fees     Fees    Fees      Fees
# Region            BE       BE       BE       BE       BE      BE        BE
# Jan Income    991.91   950.91   958.25   952.11  1006.46  978.96  960.3725
# Feb Income   1081.18  1169.62  1034.91  1085.41   905.81  949.59   1094.82
#
#                   250     251     252     253      254       255     256   \
# Business         B2C_1   B2C_2   B2C_2   B2C_2    B2C_2     B2C_2   B2C_2
# Department  Assistance    Fees    Fees    Fees     Fees      Fees    Fees
# Region              BE      BE      BE      BE       BE        BE      BE
# Jan Income     5704.25  751.75  733.71  748.66  684.335  744.5475  630.31
# Feb Income     4905.66  887.07  785.07  628.87   602.21    603.08  668.13
#
#                   257         258          259          260       261   \
# Business         B2C_1       B2C_1          B2B        B2C_2     Fleet
# Department  Assistance  Assistance  Maintenance  Maintenance  Services
# Region              BE          BE           BE           BE        BE
# Jan Income     5924.95     5924.95        438.5       455.96     450.0
# Feb Income      6458.2     4858.46       521.82       433.16     369.0
#
#                    262      263      264          265      266      267   \
# Business          B2C_2    B2C_1    B2C_1        B2C_1    B2C_1    B2C_1
# Department  Maintenance    Loans    Loans  Maintenance    Loans    Loans
# Region               BE       DE       DE           DE       DE       DE
# Jan Income       311.15  5924.95  5924.95      5924.95  5924.95  5924.95
# Feb Income       267.59  7050.69  6991.44      6813.69  7228.44  6043.45
#
#                   268      269      270      271          272      273   \
# Business         Fleet    B2C_1    B2C_1    B2C_1        B2C_1    B2C_1
# Department  Assistance    Loans    Loans    Loans  Maintenance    Loans
# Region              DE       DE       DE       DE           DE       DE
# Jan Income       19.25  5924.95  5924.95  5924.95      5924.95  5924.95
# Feb Income       17.33  5154.71  6813.69  5450.95      6635.94  5569.45
#
#                274      275      276      277      278      279      280   \
# Business      B2C_1    B2C_2    B2C_1    B2C_1    B2C_1    B2C_2    B2C_1
# Department    Loans     Fees    Loans    Loans    Loans    Loans    Loans
# Region           DE       DE       DE       DE       DE       DE       DE
# Jan Income  5924.95  5924.95  5924.95  5924.95   5722.8  5924.95  5924.95
# Feb Income  6517.45  6635.94   5628.7   6102.7  4463.78  5154.71  6932.19
#
#                281      282      283         284      285          286   \
# Business      B2C_1    B2C_1    B2C_1       B2C_1    B2C_1          B2B
# Department    Loans    Loans    Loans  Assistance    Loans  Maintenance
# Region           DE       DE       DE          DE       DE           DE
# Jan Income  5924.95  5924.95  5924.95       568.8  5924.95      5924.95
# Feb Income  6813.69  5924.95  5213.96       568.8   6102.7      6813.69
#
#                287          288      289      290       291         292   \
# Business      B2C_1        B2C_1    B2C_1    B2C_1     B2C_1         B2B
# Department    Loans  Maintenance    Loans    Loans     Loans  Assistance
# Region           DE           DE       DE       DE        DE          DE
# Jan Income  5924.95      5924.95  5924.95  5713.35  5517.175    629.0475
# Feb Income  7109.94      6813.69  5924.95  5713.35   6620.61      490.66
#
#                293      294      295      296      297      298      299   \
# Business        B2B    B2C_1    B2C_1    B2C_1    B2C_1    B2C_1    B2C_2
# Department    Loans    Loans    Loans    Loans    Loans    Loans     Fees
# Region           DE       DE       DE       DE       DE       DE       DE
# Jan Income  5924.95  5924.95  5924.95  5924.95  5924.95  5924.95  5924.95
# Feb Income  5332.46  5450.95  6635.94  5154.71  5332.46  6398.95  6576.69
#
#                300         301     302      303      304      305      306   \
# Business      B2C_1       B2C_1   B2C_2    B2C_1    B2C_1    B2C_1    B2C_1
# Department    Loans  Assistance    Fees    Loans    Loans    Loans    Loans
# Region           DE          DE      DE       DE       DE       DE       DE
# Jan Income  5924.95       750.0  5522.2  5924.95  5924.95  5736.65  5924.95
# Feb Income  4917.71       750.0  4528.2  6280.45  4562.21  7113.45  5569.45
#
#                307          308      309      310      311     312      313   \
# Business      B2C_1        B2C_1    B2C_1    B2C_1    B2C_1   B2C_1    B2C_1
# Department    Loans  Maintenance    Loans    Loans    Loans   Loans    Loans
# Region           DE           DE       DE       DE       DE      DE       DE
# Jan Income  5924.95       5420.6  5924.95  5481.95  5924.95  5709.6  5639.35
# Feb Income  5036.21      5529.01  6872.94  5153.03   5628.7  4282.2  4906.23
#
#                314      315         316      317       318      319   \
# Business      B2C_1    B2C_1       B2C_1    B2C_2     B2C_2      B2B
# Department    Loans    Loans  Assistance     Fees  Services    Loans
# Region           DE       DE          DE       DE        DE       DE
# Jan Income   5206.5  5652.75    1317.025  5070.27   5142.45  5326.16
# Feb Income  6299.87  7009.41      1330.2  4157.62   4062.54  5858.78
#
#                   320      321      322          323      324         325   \
# Business         B2C_1    B2C_2    B2C_1        B2C_1    B2C_1       B2C_1
# Department  Assistance     Fees    Loans        Loans    Loans  Assistance
# Region              DE       DE       DE           DE       DE          DE
# Jan Income     1424.25   4955.2  4827.55  4571.645192  4743.15      1510.4
# Feb Income     1424.25  5748.03  5841.34      5165.96  5454.62      1510.4
#
#                326         327         328      329      330         331   \
# Business        B2B       B2C_1       B2C_2    B2C_1    B2C_2       B2C_1
# Department    Loans  Assistance  Assistance    Loans     Fees  Assistance
# Region           DE          DE          DE       DE       DE          DE
# Jan Income   5219.2      1542.9      1682.7  4646.21  5018.57      1611.6
# Feb Income  4853.86      1542.9     1531.26  3624.04  3763.93      1611.6
#
#                    332      333        334         335      336      337   \
# Business          B2C_1    B2C_1        B2B       B2C_1    B2C_1    B2C_2
# Department  Maintenance    Loans      Loans  Assistance    Loans     Fees
# Region               DE       DE         DE          DE       DE       DE
# Jan Income      4387.85   4635.5  4744.1375      1710.0  4388.65  4430.91
# Feb Income      3817.43  4913.63    3937.63      1710.0  4739.74  4741.07
#
#                338      339          340          341      342          343   \
# Business      B2C_1    B2C_1          B2B        B2C_1    B2C_1        B2C_1
# Department    Loans    Loans  Maintenance  Maintenance    Loans  Maintenance
# Region           DE       DE           DE           DE       DE           DE
# Jan Income   4138.0   4172.4    3835.2975      4150.66   4439.3       4097.6
# Feb Income  4510.42  4589.64      4218.83      4731.75  5460.34      3360.03
#
#                    344          345      346         347     348   \
# Business          B2C_1        B2C_1    B2C_1       B2C_1   B2C_1
# Department  Maintenance  Maintenance    Loans  Assistance   Loans
# Region               DE           DE       DE          DE      DE
# Jan Income       4193.0      4224.45   3972.5     1883.35  3971.0
# Feb Income      4570.37      4984.85  4012.23     1902.18  3971.0
#
#                    349        350          351        352      353      354   \
# Business          B2C_1      B2C_2        B2C_1      B2C_2      B2B    B2C_1
# Department  Maintenance      Loans  Maintenance       Fees    Loans    Loans
# Region               DE         DE           DE         DE       DE       DE
# Jan Income       4259.4  4074.8375       3959.9  3570.9475   3525.5  3743.45
# Feb Income      3705.68    3096.88       3999.5    3963.75  3313.97  3743.45
#
#                    355          356         357      358      359   \
# Business          B2C_1          B2B       B2C_2    B2C_2    B2C_2
# Department  Maintenance  Maintenance  Assistance    Loans     Fees
# Region               DE           DE          DE       DE       DE
# Jan Income      3732.25      3706.55     2352.15   3401.9  3587.97
# Feb Income      3769.57      3484.16     1999.33  4048.26  3265.05
#
#                    360         361      362          363      364   \
# Business          B2C_1       B2C_1    B2C_2        B2C_1    B2C_2
# Department  Maintenance  Assistance     Fees  Maintenance     Fees
# Region               DE          DE       DE           DE       DE
# Jan Income      3626.65   2296.0875  3633.57       3588.1   3692.1
# Feb Income      3662.92     2296.09  3161.21       3588.1  3913.63
#
#                   365     366          367         368     369       370   \
# Business           B2B   B2C_2        B2C_1       B2C_1   B2C_1     B2C_2
# Department  Assistance    Fees   Assistance  Assistance   Loans      Fees
# Region              DE      DE           DE          DE      DE        DE
# Jan Income     2410.55  3407.4  2366.085897      2394.4  3509.1  3242.825
# Feb Income     2338.23  3543.7      2389.75      2394.4  3509.1   3696.82
#
#                371         372         373      374       375      376   \
# Business      B2C_2       B2C_1       B2C_1    B2C_2     B2C_1    B2C_1
# Department     Fees  Assistance  Assistance     Fees     Loans    Loans
# Region           DE          DE          DE       DE        DE       DE
# Jan Income   3522.5     2439.65      2447.8  3786.72  3351.475   3357.8
# Feb Income  3592.95     2439.65      2447.8  3105.11   3384.99  3391.38
#
#               377       378      379      380      381         382      383   \
# Business     B2C_1       B2B    B2C_1    B2C_2    B2C_2       B2C_1    B2C_2
# Department   Loans  Services    Loans     Fees     Fees  Assistance     Fees
# Region          DE        DE       DE       DE       DE          DE       DE
# Jan Income  3337.9   3414.75   3289.0  3223.55  3025.07      2663.1  3313.16
# Feb Income  3337.9   3175.72  3321.89  2707.78  3630.08     2689.73  3975.79
#
#               384          385         386        387       388        389   \
# Business     B2C_1        B2C_1         B2B      B2C_2     B2C_1      B2C_2
# Department   Loans  Maintenance  Assistance       Fees     Loans       Fees
# Region          DE           DE          DE         DE        DE         DE
# Jan Income  3220.2      3197.75      2463.0  3467.9575  3138.125  3172.4225
# Feb Income  3220.2      3197.75     2192.07    3953.47   3169.51    3775.18
#
#                390       391     392         393      394          395   \
# Business      B2C_2     B2C_1   B2C_1       B2C_1      B2B          B2B
# Department     Fees     Loans   Loans  Assistance    Loans  Maintenance
# Region           DE        DE      DE          DE       DE           DE
# Jan Income  3060.02  3116.375  3106.2   2851.0125  3255.96       3156.3
# Feb Income  3457.82   3147.54  3106.2     2851.01  2474.53      2777.54
#
#               396     397      398         399      400          401   \
# Business     B2C_1     B2B    B2C_2       B2C_1    B2C_2          B2B
# Department   Loans   Loans    Loans  Assistance     Fees  Maintenance
# Region          DE      DE       DE          DE       DE           DE
# Jan Income  3054.3  3527.5  2908.05     2936.75  3060.91       3157.9
# Feb Income  3054.3  3386.4  3460.58     2966.12  2662.99      2936.85
#
#                    402          403          404      405      406   \
# Business          B2C_2        B2C_2        B2C_1    B2C_2    B2C_1
# Department  Maintenance         Fees  Maintenance     Fees    Loans
# Region               DE           DE           DE       DE       DE
# Jan Income      3155.75  2966.331538     2951.825  3172.22   2940.6
# Feb Income       3566.0      2373.07      2981.34  2474.33  2970.01
#
#                    407        408          409         410          411   \
# Business          B2C_1      B2C_2        B2C_1       B2C_1        B2C_1
# Department  Maintenance       Fees  Maintenance  Assistance  Maintenance
# Region               DE         DE           DE          DE           DE
# Jan Income      2914.75  2888.9575      2901.45   3040.2875      2880.71
# Feb Income      2914.75    3380.08      2901.45     3040.29      2909.52
#
#                  412      413      414     415      416      417         418   \
# Business        B2C_2    B2C_1    B2C_2   B2C_1    B2C_2    B2C_1       B2C_1
# Department      Loans    Loans     Fees   Loans     Fees    Loans  Assistance
# Region             DE       DE       DE      DE       DE       DE          DE
# Jan Income  2668.9875  2851.45  2997.77  2846.5  3025.45  2835.35     3097.45
# Feb Income     3176.1  2879.96  2668.02  2846.5  2964.94   2863.7     3097.45
#
#                419      420      421         422         423      424   \
# Business      Fleet    B2C_2    B2C_2       B2C_1       B2C_1    B2C_2
# Department    Loans     Fees     Fees  Assistance  Assistance     Fees
# Region           DE       DE       DE          DE          DE       DE
# Jan Income  2683.75  2684.87  2626.46     3176.75   3187.3725  2888.98
# Feb Income   2576.4  2765.42  3230.55     3208.52     3219.25  2513.41
#
#                 425       426         427          428      429      430   \
# Business       B2C_2     B2C_2       B2C_1        B2C_1    B2C_2    B2C_2
# Department      Fees      Fees  Assistance  Maintenance     Fees     Fees
# Region            DE        DE          DE           DE       DE       DE
# Jan Income  2539.395  3109.345      3282.3      2639.75  2480.85  2552.66
# Feb Income   3148.85   2580.76      3282.3      2639.75  2902.59  3012.14
#
#                431          432          433        434          435   \
# Business        B2B        B2C_1        B2C_1      B2C_2        B2C_1
# Department    Loans  Maintenance  Maintenance       Fees  Maintenance
# Region           DE           DE           DE         DE           DE
# Jan Income  2580.95       2599.8       2560.0  2496.5725     2506.675
# Feb Income  3097.14       2625.8       2560.0    2296.85      2531.74
#
#                    436          437          438          439      440   \
# Business          B2C_1          B2B        B2C_1        B2C_1    B2C_2
# Department  Maintenance  Maintenance  Maintenance  Maintenance     Fees
# Region               DE           DE           DE           DE       DE
# Jan Income       2505.0       2514.6      2487.85      2472.05  2548.35
# Feb Income       2505.0      2590.04      2512.73      2496.77   2777.7
#
#                441         442         443          444        445      446   \
# Business      B2C_2       B2C_1       B2C_1        B2C_1      B2C_2    B2C_2
# Department     Fees  Assistance  Assistance  Maintenance       Fees     Fees
# Region           DE          DE          DE           DE         DE       DE
# Jan Income  2479.67     3412.55      3460.5       2424.4  2605.8825  2451.17
# Feb Income  2306.09     3446.68     3495.11      2448.64    2110.76  2377.63
#
#                   447      448      449      450         451         452   \
# Business         Fleet    B2C_2    B2C_1    B2C_1       B2C_1       B2C_1
# Department  Assistance    Loans    Loans    Loans  Assistance  Assistance
# Region              DE       DE       DE       DE          DE          DE
# Jan Income      3487.5  2326.95  2357.55  2351.95     3558.95     3559.65
# Feb Income     3034.13  2350.22  2357.55  2351.95     3558.95     3559.65
#
#                453         454          455         456      457         458   \
# Business      B2C_2       B2C_1          B2B       B2C_1    B2C_2       B2C_1
# Department     Fees  Assistance  Maintenance  Assistance     Fees  Assistance
# Region           DE          DE           DE          DE       DE          DE
# Jan Income  2317.02      3608.1  2247.007692     3622.41  2175.78      3628.2
# Feb Income  2780.42     3644.18      2449.24     3658.63  2088.75      3628.2
#
#                459          460      461      462          463      464   \
# Business        B2B        B2C_1    B2C_2    B2C_1          B2B    B2C_2
# Department    Loans  Maintenance     Fees    Loans  Maintenance    Loans
# Region           DE           DE       DE       DE           DE       DE
# Jan Income  2280.95      2243.75  2495.42  2240.35      2063.75   2297.2
# Feb Income  2600.28      2266.19  1971.38  2262.75       2311.4  2021.54
#
#                465         466        467      468         469          470   \
# Business      B2C_2       B2C_1      Fleet    B2C_2       B2C_1        B2C_1
# Department     Fees  Assistance   Services     Fees  Assistance  Maintenance
# Region           DE          DE         DE       DE          DE           DE
# Jan Income  2447.92      3683.4  2316.8375  2057.06   3716.4625      2124.05
# Feb Income  2398.96     3720.23    2757.04  2468.47     3716.46      2145.29
#
#                    471      472          473          474      475      476   \
# Business            B2B    B2C_2        B2C_2          B2B    B2C_2    B2C_2
# Department  Maintenance     Fees  Maintenance  Maintenance     Fees     Fees
# Region               DE       DE           DE           DE       DE       DE
# Jan Income     1952.525  1888.42       2180.0       2175.0  2097.86  2023.71
# Feb Income      2128.25  2001.73       2485.2       1653.0  2202.75  2003.47
#
#                    477          478      479          480          481   \
# Business          B2C_1          B2B    B2C_2        B2C_1        B2C_1
# Department  Maintenance  Maintenance     Fees  Maintenance  Maintenance
# Region               DE           DE       DE           DE           DE
# Jan Income      2026.65      1908.35   2098.1       1993.4       1975.4
# Feb Income      2046.92      2041.93  2014.18      2013.33       1975.4
#
#                  482          483          484      485     486        487   \
# Business        B2C_2          B2B          B2B    B2C_2   B2C_2      B2C_2
# Department       Fees  Maintenance  Maintenance     Fees    Fees       Fees
# Region             DE           DE           DE       DE      DE         DE
# Jan Income  1806.8325      1944.35       1852.0  1980.21  2045.2  1888.9725
# Feb Income    2258.54      1458.26      1685.32  2435.66  1574.8     1473.4
#
#                488          489      490      491      492          493   \
# Business      B2C_2        B2C_1    B2C_2    B2C_2    B2C_2        Fleet
# Department     Fees  Maintenance     Fees     Fees     Fees  Maintenance
# Region           DE           DE       DE       DE       DE           DE
# Jan Income  2007.77      1844.91  1884.32  1721.91  1791.96      1703.85
# Feb Income  1766.84      1844.91  1507.46  1463.62  1612.76      1618.66
#
#                494      495          496      497          498      499   \
# Business      B2C_2    B2C_2          B2B    B2C_2        B2C_2    B2C_2
# Department     Fees     Fees  Maintenance     Fees  Maintenance     Fees
# Region           DE       DE           DE       DE           DE       DE
# Jan Income  1771.42  1947.45      1847.45  1862.71      1670.22  1655.02
# Feb Income  1363.99  1966.92       1810.5   1993.1      1987.56  1522.62
#
#                500      501     502      503          504      505   \
# Business      B2C_2    B2C_2   B2C_2    B2C_2          B2B    Fleet
# Department     Fees     Fees    Fees     Fees  Maintenance    Loans
# Region           DE       DE      DE       DE           DE       DE
# Jan Income  1534.66  1741.25  1595.0  1589.02       1678.0  1523.15
# Feb Income  1734.17  1793.49  1531.2  1430.12       1510.2  1782.09
#
#                    506      507         508         509      510       511   \
# Business          B2C_2    B2C_2       B2C_1       B2C_1    B2C_2     B2C_2
# Department  Maintenance     Fees  Assistance  Assistance     Fees      Fees
# Region               DE       DE          DE          DE       DE        DE
# Jan Income      1559.91  1675.92      4617.8     4600.25  1480.86  1698.075
# Feb Income       1700.3  1491.57     5125.76     5704.31  1140.26   1375.44
#
#                512         513      514         515          516       517   \
# Business      B2C_2       B2C_1    B2C_2       B2C_1          B2B     B2C_2
# Department     Fees  Assistance     Fees  Assistance  Maintenance      Fees
# Region           DE          DE       DE          DE           DE        DE
# Jan Income  1475.25     4616.15  1635.35      4868.5       1558.2  1587.885
# Feb Income  1593.27     5354.73  1340.99     4138.23      1542.62   1603.76
#
#                518      519     520      521          522       523      524   \
# Business      B2C_2    B2C_2   B2C_2    B2C_2        B2C_2     B2C_2    B2C_2
# Department     Fees     Fees    Fees     Fees  Maintenance  Services     Fees
# Region           DE       DE      DE       DE           DE        DE       DE
# Jan Income  1361.22   1322.3  1459.2  1412.01      1445.75   1407.85  1399.97
# Feb Income  1619.85  1441.31  1269.5  1510.85       1633.7   1365.61  1203.97
#
#                    525          526      527          528          529   \
# Business            B2B          B2B    B2C_2        B2C_1          B2B
# Department  Maintenance  Maintenance     Fees   Assistance  Maintenance
# Region               DE           DE       DE           DE           DE
# Jan Income       1470.0      1331.65  1299.71  4987.001603       1338.2
# Feb Income       1131.9      1318.33  1598.64      4139.21      1311.44
#
#                    530       531      532          533          534      535   \
# Business          B2C_1     B2C_2    B2C_2          B2B        B2C_1    B2C_2
# Department  Maintenance      Fees     Fees  Maintenance  Maintenance     Fees
# Region               DE        DE       DE           DE           DE       DE
# Jan Income      1296.66  1205.585   1379.8      1353.65       1211.3  1228.77
# Feb Income      1309.63   1181.47  1103.84      1245.36      1223.41   1302.5
#
#                    536     537      538          539      540          541   \
# Business          B2C_2   B2C_2    B2C_2        Fleet    B2C_2        B2C_2
# Department  Maintenance    Fees     Fees  Maintenance     Fees  Maintenance
# Region               DE      DE       DE           DE       DE           DE
# Jan Income       1307.2  1230.8  1133.05       1166.0  1099.01      1176.25
# Feb Income      1045.76  1390.8  1110.39      1294.26  1263.86       976.29
#
#                542       543        544         545       546      547   \
# Business      B2C_2     Fleet      B2C_2       B2C_1     B2C_2    B2C_2
# Department     Fees  Services       Fees  Assistance  Services     Fees
# Region           DE        DE         DE          DE        DE       DE
# Jan Income  1170.51   1082.85  1065.2075      5629.9   1060.96  1135.76
# Feb Income  1287.56   1245.28    1310.21     6418.09    933.64   954.04
#
#                   548          549      550          551       552     553   \
# Business         B2C_1        B2C_2    B2C_2          B2B     B2C_2   B2C_2
# Department  Assistance  Maintenance     Fees  Maintenance      Fees    Fees
# Region              DE           DE       DE           DE        DE      DE
# Jan Income     5924.95        958.0  1025.22        995.0  1001.135  966.12
# Feb Income      5510.2        718.5  1127.74      1243.75    750.85  734.25
#
#                 554      555      556     557     558         559      560   \
# Business       B2C_2    B2C_2    B2C_2   B2C_2   B2C_2       B2C_1    B2C_2
# Department      Fees     Fees     Fees    Fees    Fees  Assistance     Fees
# Region            DE       DE       DE      DE      DE          DE       DE
# Jan Income  1019.375   964.05   913.01  962.61  923.36     5924.95   864.81
# Feb Income   1243.64  1031.53  1104.74  914.48  1043.4     6754.44  1063.72
#
#                561     562      563          564       565      566     567   \
# Business      B2C_2   B2C_2    B2C_2        B2C_2     Fleet    B2C_2   B2C_2
# Department     Fees    Fees     Fees  Maintenance  Services     Fees    Fees
# Region           DE      DE       DE           DE        DE       DE      DE
# Jan Income    955.1  916.81    909.1        821.5   1012.36  856.085  967.31
# Feb Income  1031.51  916.81  1136.38       944.73    850.38   941.69   754.5
#
#               568     569     570     571     572      573     574   \
# Business     B2C_2   B2C_2   B2C_2   B2C_2   B2C_2    B2C_2   B2C_2
# Department    Fees    Fees    Fees    Fees    Fees     Fees    Fees
# Region          DE      DE      DE      DE      DE       DE      DE
# Jan Income  890.76  812.31  787.41  848.01   905.4  780.125  707.61
# Feb Income  730.42  869.17  874.03  703.85  923.51   912.75  834.98
#
#                    575    576         577     578     579     580   \
# Business            B2B  B2C_2       B2C_1   B2C_2   B2C_2   B2C_2
# Department  Maintenance   Fees  Assistance    Fees    Fees    Fees
# Region               DE     DE          DE      DE      DE      DE
# Jan Income        738.5  786.0     5924.95  764.36  626.36  804.06
# Feb Income        590.8  589.5     6576.69  733.79   739.1  603.05
#
#                    581       582     583       584       585         586   \
# Business          B2C_2     B2C_2   B2C_2     Fleet     Fleet       B2C_1
# Department  Maintenance      Fees    Fees  Services     Loans  Assistance
# Region               DE        DE      DE        DE        DE          DE
# Jan Income        731.5  673.6375  654.61     520.0  590.6125     5924.95
# Feb Income        731.5     815.1  523.69     650.0    626.05     6576.69
#
#                 587    588       589       590       591     592   \
# Business       B2C_2  B2C_2     Fleet     Fleet       B2B   B2C_2
# Department  Services   Fees  Services  Services  Services    Fees
# Region            DE     DE        DE        DE        DE      DE
# Jan Income    396.15  350.0     355.0  312.4875    297.65  273.16
# Feb Income     380.3  269.5    273.35    371.86    235.14  273.16
#
#                    593       594         595    596      597      598   \
# Business          B2C_2     B2C_2       B2C_1  B2C_2    B2C_1    B2C_1
# Department  Maintenance  Services  Assistance  Loans    Loans    Loans
# Region               DE        DE          DE     DE       DK       DK
# Jan Income       207.76     134.6     5924.95    0.0  5924.95  5924.95
# Feb Income       191.14    135.95     6517.45    0.0  7406.19  7228.44
#
#                599      600      601         602         603      604   \
# Business      B2C_1    B2C_1      B2B       Fleet       B2C_2    B2C_1
# Department    Loans    Loans    Loans  Assistance  Assistance    Loans
# Region           DK       DK       DK          DK          DK       DK
# Jan Income  5924.95  5924.95  5684.85      461.55      541.25  5924.95
# Feb Income  4739.96  6635.94  6935.52      567.71      638.68  7109.94
#
#                605      606      607          608          609      610   \
# Business      B2C_1    B2C_1    B2C_1        B2C_1        B2C_1    B2C_1
# Department    Loans    Loans    Loans  Maintenance  Maintenance    Loans
# Region           DK       DK       DK           DK           DK       DK
# Jan Income  5924.95  5924.95  5924.95      5924.95      5192.95  5924.95
# Feb Income  6043.45  5569.45  7169.19       5984.2      6127.68  4621.46
#
#                611          612      613      614          615        616   \
# Business      B2C_1        B2C_1      B2B    B2C_1        B2C_1      B2C_2
# Department    Loans  Maintenance    Loans    Loans        Loans       Fees
# Region           DK           DK       DK       DK           DK         DK
# Jan Income  5924.95      5924.95  5924.95  5924.95  5213.973077  5126.5875
# Feb Income  4443.71      7050.69  4739.96  5687.95      6048.21    5434.18
#
#                  617      618          619     620      621        622   \
# Business        B2C_2    B2C_1        B2C_1   B2C_1    B2C_1      B2C_1
# Department       Fees    Loans  Maintenance   Loans    Loans      Loans
# Region             DK       DK           DK      DK       DK         DK
# Jan Income  4715.9375  5924.95      5162.15  5141.9   5008.7  5327.2625
# Feb Income    5706.28  4917.71      4697.56  5399.0  5910.27    5167.44
#
#                623      624          625      626      627          628   \
# Business      B2C_2    B2C_1        B2C_1    B2C_2    B2C_1        B2C_1
# Department    Loans    Loans  Maintenance     Fees    Loans  Maintenance
# ...
# Feb Income  1374.68  1490.7  1106.15  1230.15  1150.36   1105.91   1053.0
#
#                    1730     1731         1732      1733     1734         1735  \
# Business          B2C_2    B2C_2        B2C_2     B2C_2    B2C_2        Fleet
# Department  Maintenance     Fees  Maintenance      Fees     Fees  Maintenance
# Region               PT       PT           PT        PT       PT           PT
# Jan Income      1117.25  1196.62       1084.2  1167.235  1066.15       1014.6
# Feb Income       860.28  1172.69       813.15    980.48   852.92       984.16
#
#                    1736         1737         1738      1739      1740  \
# Business            B2B        Fleet          B2B     B2C_2     B2C_2
# Department  Maintenance  Maintenance  Maintenance      Fees      Fees
# Region               PT           PT           PT        PT        PT
# Jan Income       1000.2        897.2       937.91  821.7475  866.3475
# Feb Income        980.2      1076.64       815.98    945.01    675.75
#
#                    1741    1742    1743   1744        1745    1746  \
# Business          B2C_2   B2C_2   B2C_2  B2C_2       B2C_1   B2C_2
# Department  Maintenance    Fees    Fees   Fees  Assistance    Fees
# Region               PT      PT      PT     PT          PT      PT
# Jan Income       805.56  743.76  729.81  550.0     5709.25  453.76
# Feb Income       700.84  855.32  897.67  550.0     6508.55  408.38
#
#                    1747         1748      1749         1750      1751  \
# Business          Fleet        B2C_2     Fleet        B2C_2     B2C_2
# Department  Maintenance  Maintenance  Services  Maintenance  Services
# Region               PT           PT        PT           PT        PT
# Jan Income        420.0        360.0     300.0        251.5       0.0
# Feb Income        327.6        414.0     273.0       291.74       0.0
#
#                1752     1753     1754     1755     1756     1757     1758  \
# Business      B2C_1    B2C_1    B2C_1    B2C_1    B2C_1    B2C_1    B2C_1
# Department    Loans    Loans    Loans    Loans    Loans    Loans    Loans
# Region           UK       UK       UK       UK       UK       UK       UK
# Jan Income   5665.9  5924.95  5924.95  5924.95  5773.65  5924.95  5924.95
# Feb Income  7082.38   5865.7  6517.45  7109.94   6004.6  4443.71   5510.2
#
#                   1759     1760     1761         1762     1763     1764  \
# Business         B2C_1    B2C_1    B2C_1        B2C_1    B2C_2    B2C_1
# Department  Assistance    Loans    Loans  Maintenance     Fees    Loans
# Region              UK       UK       UK           UK       UK       UK
# Jan Income       200.0  5924.95  5924.95      5924.95  5924.95  5924.95
# Feb Income         0.0  6517.45  6991.44      6517.45  7169.19  5332.46
#
#                   1765     1766     1767     1768     1769     1770     1771  \
# Business         Fleet    B2C_1    B2C_2    B2C_2    B2C_1    B2C_1    B2C_1
# Department  Assistance    Loans     Fees     Fees    Loans    Loans    Loans
# Region              UK       UK       UK       UK       UK       UK       UK
# Jan Income     375.125  5924.95   5574.4   5809.5  5924.95  5924.95  5924.95
# Feb Income      408.89  6280.45  6689.28  6390.45  5036.21  6872.94   5628.7
#
#                1772     1773     1774      1775     1776     1777     1778  \
# Business      B2C_1      B2B    B2C_2     Fleet    B2C_2    B2C_1    B2C_2
# Department    Loans    Loans    Loans  Services     Fees    Loans     Fees
# Region           UK       UK       UK        UK       UK       UK       UK
# Jan Income  5924.95  5680.81  5924.95   5924.95  5924.95  5924.95  5924.95
# Feb Income  4621.46  5964.85  6754.44   5569.45  5095.46   6458.2   6221.2
#
#                1779        1780     1781         1782     1783     1784  \
# Business      B2C_1       B2C_1    B2C_2        B2C_1    B2C_2    B2C_1
# Department    Loans  Assistance     Fees  Maintenance     Fees    Loans
# Region           UK          UK       UK           UK       UK       UK
# Jan Income  5924.95      721.15  5924.95      5924.95  5924.95  5869.15
# Feb Income  6872.94      728.36  6517.45      6635.94  5687.95  5458.31
#
#                   1785     1786        1787     1788     1789     1790  \
# Business           B2B    B2C_1         B2B    B2C_1    B2C_1    B2C_2
# Department  Assistance    Loans  Assistance    Loans    Loans    Loans
# Region              UK       UK          UK       UK       UK       UK
# Jan Income      787.25   5742.1       950.0  5924.95  5924.95  5924.95
# Feb Income       944.7  5110.47       788.5  6280.45  5450.95  5154.71
#
#                1791     1792     1793     1794     1795     1796       1797  \
# Business      B2C_1    B2C_1    B2C_1    B2C_1    B2C_2    B2C_1      B2C_1
# Department    Loans    Loans    Loans    Loans     Fees    Loans      Loans
# Region           UK       UK       UK       UK       UK       UK         UK
# Jan Income  5924.95  5924.95  5556.25  5924.95  5924.95  5924.95  5682.5375
# Feb Income  6398.95  4621.46  4667.25  5450.95   5391.7  4443.71    5455.24
#
#                 1798     1799     1800     1801        1802     1803     1804  \
# Business       B2C_1    B2C_2    B2C_1      B2B       B2C_1    B2C_1    B2C_1
# Department     Loans     Fees    Loans    Loans  Assistance    Loans    Loans
# Region            UK       UK       UK       UK          UK       UK       UK
# Jan Income  5129.625  5409.15  5022.55  5924.95     1222.05  5924.95  5924.95
# Feb Income   3847.22  4165.05   5323.9  5450.95     1234.27  5332.46  5154.71
#
#                1805     1806     1807        1808     1809        1810  \
# Business      B2C_1    B2C_1    B2C_1       B2C_1    B2C_1       B2C_1
# Department    Loans    Loans    Loans  Assistance    Loans  Assistance
# Region           UK       UK       UK          UK       UK          UK
# Jan Income  5924.95  5924.95   4993.3     1524.45  4847.25     1530.95
# Feb Income  5095.46  5332.46  4094.51     1524.45  4701.83     1546.26
#
#                  1811       1812      1813     1814      1815     1816  \
# Business        B2C_1      B2C_2     B2C_2    B2C_1     B2C_2    B2C_1
# Department      Loans       Fees     Loans    Loans  Services    Loans
# Region             UK         UK        UK       UK        UK       UK
# Jan Income  4345.8625  4549.3725  4694.875  4450.85    4367.6  4387.25
# Feb Income    5128.12    4913.32   4694.88  4050.27   4105.54  3290.44
#
#                  1817        1818     1819     1820     1821      1822  \
# Business        B2C_1       B2C_1    B2C_1    B2C_1      B2B     B2C_1
# Department      Loans  Assistance    Loans    Loans    Loans     Loans
# Region             UK          UK       UK       UK       UK        UK
# Jan Income  4060.8625     1727.45  4030.35   4137.9  4163.75  4050.675
# Feb Income    4263.91     1744.72  4231.87  3806.87  4080.48   4334.22
#
#                    1823        1824        1825         1826        1827  \
# Business          B2C_1       B2C_1       B2C_1        B2C_1       B2C_1
# Department  Maintenance  Assistance  Assistance  Maintenance  Assistance
# Region               UK          UK          UK           UK          UK
# Jan Income      4194.15     1883.66      1888.2       3890.8     1982.85
# Feb Income      3523.09     1883.66      1888.2       3890.8     2002.68
#
#               1828     1829         1830     1831       1832     1833  \
# Business     B2C_1    B2C_2        B2C_1    B2C_1      B2C_1    B2C_1
# Department   Loans     Fees  Maintenance    Loans      Loans    Loans
# Region          UK       UK           UK       UK         UK       UK
# Jan Income  3845.0  3845.66       3825.0  4211.85  3772.1375  3753.65
# Feb Income  3845.0   4076.4      3863.25  3790.67    3772.14  3753.65
#
#                 1834    1835     1836       1837        1838      1839  \
# Business       Fleet   B2C_1    B2C_1      B2C_1         B2B     B2C_1
# Department  Services   Loans    Loans      Loans  Assistance  Services
# Region            UK      UK       UK         UK          UK        UK
# Jan Income   3959.35  3464.2  3392.55  3390.7375    2616.575    3286.4
# Feb Income   3800.98  3464.2  3426.48    3424.64      2747.4   3319.26
#
#                    1840      1841      1842      1843       1844        1845  \
# Business            B2B     B2C_2     B2C_2     B2C_2      B2C_2       B2C_1
# Department  Maintenance  Services      Fees      Fees       Fees  Assistance
# Region               UK        UK        UK        UK         UK          UK
# Jan Income       3030.1   3102.35  3229.725  3217.235  3286.1725      2818.7
# Feb Income      3545.22   3412.59    3520.4   3925.03    2858.97      2818.7
#
#                   1846         1847         1848     1849         1850  \
# Business           B2B        B2C_1        B2C_1      B2B        B2C_1
# Department  Assistance  Maintenance  Maintenance    Loans  Maintenance
# Region              UK           UK           UK       UK           UK
# Jan Income     2984.55  2999.385897       2987.2   2988.1      2906.75
# Feb Income     3700.84      2999.39      3017.07  3077.74      2906.75
#
#                    1851     1852         1853     1854     1855         1856  \
# Business          B2C_1    Fleet        B2C_1    B2C_2    B2C_2        B2C_1
# Department  Maintenance    Loans  Maintenance     Fees     Fees  Maintenance
# Region               UK       UK           UK       UK       UK           UK
# Jan Income       2904.5  3006.45       2871.5  3026.75  2686.65    2844.2625
# Feb Income       2904.5  3697.93       2871.5  2724.08  3143.38      2872.71
#
#                    1857     1858      1859         1860     1861     1862  \
# Business          B2C_1    B2C_2     Fleet        B2C_1    B2C_2    B2C_2
# Department  Maintenance     Fees  Services  Maintenance    Loans    Loans
# Region               UK       UK        UK           UK       UK       UK
# Jan Income       2764.2  2742.66   2548.55      2654.85  2718.47  2591.25
# Feb Income      2791.84  2440.97   2625.01      2654.85  2718.47  2591.25
#
#                    1863     1864         1865         1866        1867  \
# Business          B2C_2    B2C_2        B2C_1        B2C_1       B2C_1
# Department  Maintenance     Fees  Maintenance  Maintenance  Assistance
# Region               UK       UK           UK           UK          UK
# Jan Income       2843.4   2720.6       2509.0      2491.95     3481.25
# Feb Income       2758.1  2176.48       2509.0      2516.87     3516.06
#
#                1868        1869         1870         1871        1872  \
# Business      B2C_2       B2C_1          B2B          B2B       B2C_1
# Department     Fees  Assistance  Maintenance  Maintenance  Assistance
# Region           UK          UK           UK           UK          UK
# Jan Income  2273.55      3477.5       2631.0      2620.35     3507.36
# Feb Income  2023.46     3512.28      2078.49      2332.11     3542.43
#
#                    1873     1874         1875         1876        1877  \
# Business            B2B    B2C_2        B2C_1        B2C_1       B2C_1
# Department  Maintenance     Fees  Maintenance  Maintenance  Assistance
# Region               UK       UK           UK           UK          UK
# Jan Income       2350.7  2462.86      2290.31    2175.6875      3702.7
# Feb Income      2938.38  2019.55      2313.21      2197.44      3702.7
#
#                1878      1879         1880         1881     1882       1883  \
# Business      B2C_2     Fleet          B2B        B2C_2    B2C_2      B2C_2
# Department     Fees  Services  Maintenance  Maintenance     Fees       Fees
# Region           UK        UK           UK           UK       UK         UK
# Jan Income  2296.45    2020.0     2134.425     2013.075   2154.5  1951.8725
# Feb Income   1814.2    1979.6      1643.51      2455.95  1831.33    2166.58
#
#                   1884         1885         1886      1887     1888     1889  \
# Business           B2B        B2C_1          B2B       B2B    B2C_2    B2C_2
# Department  Assistance  Maintenance  Maintenance  Services     Fees     Fees
# Region              UK           UK           UK        UK       UK       UK
# Jan Income     3791.55      1919.85       1963.1    1780.1  1826.95  1525.25
# Feb Income     4284.45      1939.05      1668.64   1655.49  1717.33  1342.22
#
#                    1890     1891      1892         1893         1894  \
# Business          B2C_2    B2C_1     Fleet          B2B        B2C_1
# Department  Maintenance    Loans  Services  Maintenance  Maintenance
# Region               UK       UK        UK           UK           UK
# Jan Income      1657.85  1567.25    1461.5      1473.85      1500.15
# Feb Income      2022.58  1567.25   1549.19      1694.93      1500.15
#
#                   1895     1896         1897        1898         1899  \
# Business         B2C_1    B2C_1          B2B       B2C_1          B2B
# Department  Assistance    Loans  Maintenance  Assistance  Maintenance
# Region              UK       UK           UK          UK           UK
# Jan Income      4714.9   1443.0      1493.25     4722.06       1488.0
# Feb Income     5610.73  1457.43      1657.51      5052.6      1681.44
#
#                1900     1901     1902         1903     1904        1905  \
# Business      B2C_2    B2C_2    B2C_2          B2B    B2C_2       B2C_1
# Department     Fees     Fees     Fees  Maintenance     Fees  Assistance
# Region           UK       UK       UK           UK       UK          UK
# Jan Income  1493.22   1406.2  1506.96       1336.2   1367.8     5063.85
# Feb Income  1538.02  1195.27  1250.78      1483.18  1299.41     6076.62
#
#                 1906     1907     1908      1909        1910     1911  \
# Business       Fleet    B2C_2    B2C_2     B2C_2       B2C_1    B2C_2
# Department  Services     Fees     Fees      Fees  Assistance     Fees
# Region            UK       UK       UK        UK          UK       UK
# Jan Income   1235.25  1279.81  1260.65  1129.875     5924.95  1139.25
# Feb Income   1507.01  1049.44  1500.17   1016.89     7406.19  1002.54
#
#                1912     1913     1914       1915     1916     1917    1918  \
# Business      B2C_2    B2C_2    B2C_2      B2C_2    B2C_2    B2C_2   B2C_2
# Department     Fees     Fees     Fees      Loans     Fees     Fees    Fees
# Region           UK       UK       UK         UK       UK       UK      UK
# Jan Income  1120.21  1102.21   1023.9  1026.1125  1168.41   1008.9  922.65
# Feb Income  1288.24   892.79  1054.62     882.46  1004.83  1220.77  701.21
#
#               1919      1920         1921      1922    1923      1924    1925  \
# Business     B2C_2     B2C_2        B2C_2     B2C_2   B2C_2     B2C_2   B2C_2
# Department    Fees  Services  Maintenance  Services    Fees  Services    Fees
# Region          UK        UK           UK        UK      UK        UK      UK
# Jan Income  805.71     857.4       712.05     735.5   760.1     751.5  720.21
# Feb Income  982.97    883.12        797.5     654.6  881.72    856.71  540.16
#
#               1926      1927    1928        1929      1930   1931  \
# Business     B2C_2     B2C_2   B2C_2       B2C_1     B2C_2  B2C_2
# Department    Fees  Services    Fees  Assistance  Services  Loans
# Region          UK        UK      UK          UK        UK     UK
# Jan Income  753.85     697.9   662.5     5924.95     602.4  600.0
# Feb Income  753.85    774.67  589.63     4976.96    572.28  486.0
#
#                    1932        1933         1934   1935   1936
# Business          B2C_2       B2C_1          B2B  B2C_2  B2C_2
# Department  Maintenance  Assistance  Maintenance   Fees   Fees
# Region               UK          UK           UK     UK     UK
# Jan Income       562.75     5924.95        480.0  400.0  20.21
# Feb Income        512.1     6991.44        393.6  464.0  19.81

# %%
df_next_t = df_next.T
print(df_next_t.shape)
df_next_t.head()
# Out:
# (2, 1937)
# Region                     AT                                         \
# Business                B2C_1
# Department              Loans        Loans        Loans     Services
# July Income       5668.401744  4171.916517  1330.935798  4416.591440
# July Expenditure  1344.650764  3681.710708   911.586699  1657.135837
#
# Region                                                                \
# Business
# Department              Loans        Loans        Loans        Loans
# July Income       4136.017540  2485.707305  3315.317734  4750.327765
# July Expenditure  5330.310997  2203.774721  1460.735427   744.838461
#
# Region                                                              \
# Business                              B2B        B2C_1
# Department              Loans  Assistance  Maintenance Maintenance
# July Income       1139.120130  333.708904  2420.907444  500.991416
# July Expenditure   192.939012  910.119156   457.363930  456.360602
#
# Region                                                               \
# Business                            Fleet        B2C_1
# Department              Loans  Assistance  Maintenance   Assistance
# July Income       4897.753525  472.172041  3716.156171  1054.852997
# July Expenditure   706.813631  756.212824  1448.568592  2455.129010
#
# Region                                                                \
# Business
# Department              Loans        Loans  Maintenance        Loans
# July Income       1798.020393  3836.332828  2245.572292  2472.554968
# July Expenditure   959.206951  1096.835592   566.853388  2637.568132
#
# Region                                                                \
# Business                B2C_2        B2C_1                       B2B
# Department               Fees  Maintenance        Loans   Assistance
# July Income         80.557083  3196.494624  1445.575374  1253.741111
# July Expenditure  2406.768749   305.478207  1590.628364  2011.317991
#
# Region                                                                \
# Business                B2C_1        B2C_2        B2C_1
# Department         Assistance         Fees   Assistance        Loans
# July Income       1253.008062  3783.530256  1102.555345     7.924235
# July Expenditure   445.058157  1896.356725   986.827573  3766.287656
#
# Region                                                                \
# Business                B2C_2                     B2C_1        B2C_2
# Department               Fees         Fees   Assistance         Fees
# July Income       3751.339030  2450.181459  1169.335316  3017.860685
# July Expenditure  2107.735719  1449.399672    98.835929  1201.558637
#
# Region                                                              \
# Business                            B2C_1         B2B        B2C_1
# Department              Fees  Maintenance  Assistance   Assistance
# July Income        56.096716  3528.970902  454.099381  1589.550858
# July Expenditure  334.794525   175.035857  908.984937  1152.910871
#
# Region                                                              \
# Business                                        B2C_2        B2C_1
# Department             Loans       Loans         Fees  Maintenance
# July Income       191.653999  911.973804   597.430700    70.002665
# July Expenditure   73.723297  867.424118  2417.259034  1047.541263
#
# Region                                                              \
# Business                                                     B2C_2
# Department        Maintenance  Maintenance  Assistance        Fees
# July Income       1905.688586  1434.183887  128.470464  482.018594
# July Expenditure   909.039175   725.258144  335.508362  287.292734
#
# Region                                                              \
# Business                B2C_1                                B2C_2
# Department         Assistance  Assistance  Maintenance Maintenance
# July Income       2566.689731  370.212073  1390.870413  772.873098
# July Expenditure   952.089798  581.565146   415.624155  685.295751
#
# Region                                                               \
# Business                B2C_1       B2C_2
# Department         Assistance        Fees     Services         Fees
# July Income       2915.659424   50.883983  1395.376532  1599.143981
# July Expenditure  2162.714821  131.392191  1555.502310   796.360973
#
# Region                                                              \
# Business                B2C_1                      B2B       B2C_2
# Department              Loans   Assistance       Loans        Fees
# July Income       1214.998511   600.191819  508.608485  740.520675
# July Expenditure  4468.287166  1799.710306  303.193904  699.418610
#
# Region                                                               \
# Business                B2C_1         B2B        B2C_1        B2C_2
# Department        Maintenance Maintenance        Loans  Maintenance
# July Income       2011.312071  457.389584  1445.528366  1040.737097
# July Expenditure  3310.920404  611.946017  3840.517865   458.093556
#
# Region                                                                         \
# Business                            B2C_1         B2B       B2C_1
# Department              Loans Maintenance Maintenance Maintenance       Loans
# July Income       2156.942097   84.978809  1445.75951  179.810414  408.792713
# July Expenditure   606.206954  129.432188   725.28958  853.764077  376.916368
#
# Region                                                                         \
# Business               B2C_2       Fleet        B2C_1         B2B       B2C_1
# Department              Fees    Services        Loans       Loans Maintenance
# July Income       575.050909  486.262018  1511.613733  714.420924  218.163087
# July Expenditure  445.897051  479.905152  1670.516830  993.625668  442.768614
#
# Region                                                                         \
# Business                B2C_2       B2C_1       B2C_2         B2B       B2C_2
# Department        Maintenance Maintenance Maintenance Maintenance        Fees
# July Income        814.840716  740.224431  441.177925  769.167997  496.934701
# July Expenditure  1005.369897  374.965817  437.310694  258.135978  660.882484
#
# Region                                                             \
# Business                              B2B       B2C_2
# Department              Fees  Maintenance        Fees        Fees
# July Income       214.713974   891.829870  946.499860  636.265239
# July Expenditure   34.667094  1153.072862  580.809892  384.730623
#
# Region                                                                         \
# Business
# Department               Fees    Services Maintenance Maintenance        Fees
# July Income       1114.463331  399.341721  517.034331  531.860778  296.999760
# July Expenditure   375.219823  445.889385   67.620049   95.528793  370.531848
#
# Region                                                                        \
# Business                                        B2C_1                  B2C_2
# Department              Fees         Fees  Assistance Assistance        Fees
# July Income       414.418001  1918.887675  203.378168  249.09039  411.008328
# July Expenditure  192.709125  2529.266766  381.936046  118.24237   54.603637
#
# Region                                                                         \
# Business                                                                Fleet
# Department             Fees         Fees    Services        Fees     Services
# July Income       92.789376   112.343601  235.841176  212.802617  5558.109721
# July Expenditure  39.691904  1096.221265   34.722459  561.136397  2197.577489
#
# Region                                                               \
# Business                B2C_2        Fleet       B2C_2
# Department              Loans     Services        Fees         Fees
# July Income        401.297601  4932.484304    5.787613   177.106917
# July Expenditure  1523.717716   486.187994  205.612640  6158.494765
#
# Region                                                                \
# Business                B2C_1        B2C_2                     Fleet
# Department         Assistance  Maintenance         Fees         Fees
# July Income       6945.404569  3678.921734  2739.597199  4250.640528
# July Expenditure  3191.831626  5206.275201    79.940370  3206.768966
#
# Region                                                               \
# Business                             B2C_1       Fleet
# Department           Services  Maintenance    Services     Services
# July Income       3357.392921  5124.472644  152.483426  4279.927978
# July Expenditure  1393.219744   104.768645  987.751660  2063.514908
#
# Region                     BE                                        \
# Business                  B2B        B2C_1                    B2C_2
# Department              Loans        Loans        Loans  Assistance
# July Income        827.712877  1935.773338  5216.841299   38.444645
# July Expenditure  2786.733188  1507.946210  4783.965973  867.026829
#
# Region                                                                \
# Business                B2C_1                       B2B        B2C_1
# Department              Loans        Loans        Loans        Loans
# July Income       2328.047398    12.992309  1311.264391  4269.441401
# July Expenditure  1404.700079  2365.942482    56.886677  2110.886081
#
# Region                                                             \
# Business
# Department             Loans       Loans        Loans Maintenance
# July Income       601.371442  343.798501  2380.463492  619.344113
# July Expenditure  583.030086  238.336600  4011.119279  236.581139
#
# Region                                                                \
# Business                  B2B        B2C_1
# Department              Loans        Loans        Loans        Loans
# July Income          4.253506  5423.515275   755.360452  4183.803670
# July Expenditure  1173.170786   412.214718  2501.087314  3365.216395
#
# Region                                                               \
# Business                            B2C_2        B2C_1
# Department        Assistance         Fees        Loans  Maintenance
# July Income       757.752225   280.808068  4167.485989  2355.127343
# July Expenditure  403.515644  2156.787264   775.464206  1054.372236
#
# Region                                                               \
# Business
# Department             Loans   Assistance  Maintenance        Loans
# July Income       478.874927   173.818256   983.956096  4019.325375
# July Expenditure  720.980191  1243.983423  4055.192770  1611.856751
#
# Region                                                               \
# Business
# Department         Assistance   Assistance       Loans        Loans
# July Income       3709.569647  2442.784117  1277.14095  5103.709874
# July Expenditure   749.754557   698.776812  2687.24108  1071.924590
#
# Region                                                                \
# Business                               B2B        B2C_2        B2C_1
# Department              Loans        Loans        Loans        Loans
# July Income       2019.520423  1981.188617  3279.679915  1971.628635
# July Expenditure  3558.649759  1269.386204  1675.262063  3054.323279
#
# Region                                                                \
# Business                             B2C_2                     B2C_1
# Department        Maintenance   Assistance   Assistance        Loans
# July Income        847.627614  1742.627539  2197.262926  1265.200432
# July Expenditure  3220.349579   742.792584  1923.178446  1395.636639
#
# Region                                                                \
# Business                                                       B2C_2
# Department              Loans  Maintenance   Assistance         Fees
# July Income        586.595334  1858.570164  3315.172901  3091.719516
# July Expenditure  1306.594277  1897.885772   647.529158   229.129091
#
# Region                                                                \
# Business                B2C_1                                  B2C_2
# Department              Loans   Assistance        Loans         Fees
# July Income       1529.963185  3909.031277  1246.444112  2956.434439
# July Expenditure  1267.485100  2314.028747    15.301670  1128.930577
#
# Region                                                                \
# Business                  B2B        B2C_1
# Department           Services  Maintenance  Maintenance        Loans
# July Income       2240.016973   177.922029  1697.903726  1618.934550
# July Expenditure   814.302308  3063.519361  2616.269467    24.315951
#
# Region                                                                \
# Business                                                         B2B
# Department              Loans  Maintenance        Loans        Loans
# July Income       1816.764504  1623.410593  2051.231057  2313.470938
# July Expenditure    45.092088  1598.546336   127.124258  2113.986070
#
# Region                                                               \
# Business               B2C_2                     B2C_1
# Department             Loans         Fees        Loans  Maintenance
# July Income       597.433352  2057.218006  1876.223671   402.222242
# July Expenditure  950.098378   953.966486  2477.010584  1477.333494
#
# Region                                                              \
# Business
# Department       Maintenance Maintenance  Maintenance        Loans
# July Income       821.160149   69.677970  1200.360585  2941.343903
# July Expenditure  549.111820  785.021138   245.815454  1863.970597
#
# Region                                                                \
# Business                  B2B        B2C_2        B2C_1        B2C_2
# Department         Assistance         Fees   Assistance         Fees
# July Income       1004.720645   204.034349  1242.986090  2435.749052
# July Expenditure  1383.470445  1028.244056   774.418893    66.839753
#
# Region                                                                \
# Business                               B2B        B2C_1          B2B
# Department               Fees     Services        Loans  Maintenance
# July Income       1193.156265  1465.175802  1813.537982  1502.714979
# July Expenditure   844.874231  1445.307286  1319.884474   362.774437
#
# Region                                                               \
# Business                B2C_1
# Department        Maintenance Maintenance        Loans        Loans
# July Income       1333.182683  357.432450   792.990129  1370.701092
# July Expenditure   574.536664  931.762689  2113.068171   201.017970
#
# Region                                                                \
# Business                B2C_2                       B2B        B2C_2
# Department               Fees         Fees  Maintenance         Fees
# July Income       2992.874853  1245.107231  1821.658925  2263.327357
# July Expenditure  1315.823346  1086.367082   214.052432  1392.848015
#
# Region                                                                \
# Business                  B2B        B2C_1        B2C_2          B2B
# Department        Maintenance  Maintenance         Fees  Maintenance
# July Income       1789.538203   328.153521  1661.139084  1346.155069
# July Expenditure  1558.076736  1151.557305   571.587909   270.409167
#
# Region                                                              \
# Business               B2C_1        B2C_2                    B2C_1
# Department       Maintenance         Fees        Fees        Loans
# July Income       608.542765  1342.721411  306.422555   551.054324
# July Expenditure  117.257284  1261.853156  939.610100  1181.337931
#
# Region                                                              \
# Business                            B2C_2                    B2C_1
# Department             Loans         Fees        Loans       Loans
# July Income       489.498532  1497.263727  1624.770459  629.969162
# July Expenditure  193.127253   646.601587  1580.010329  445.148487
#
# Region                                                              \
# Business                B2C_2       B2C_1       B2C_2          B2B
# Department               Fees  Assistance        Fees   Assistance
# July Income       1994.933174  396.376712  168.732802  1224.667761
# July Expenditure  1332.506405  411.509747  637.680031   453.046105
#
# Region                                                               \
# Business                B2C_2
# Department               Fees         Fees        Fees        Loans
# July Income       1728.060491  1378.466561  131.062278  1242.511313
# July Expenditure  1616.150913   353.995482  657.620334  1306.978385
#
# Region                                                                         \
# Business                                        B2C_1       B2C_2
# Department              Fees         Fees Maintenance        Fees        Fees
# July Income       385.845109   436.764600  362.064619  472.862961  133.479104
# July Expenditure   35.377941  1145.716513  314.904122  126.678830  815.311938
#
# Region                                                                         \
# Business                            B2C_1                     B2B       B2C_2
# Department           Services       Loans Maintenance       Loans        Fees
# July Income       1577.888969  851.695473    49.95242  313.522973  131.269060
# July Expenditure   508.055619  627.699714   889.30557   27.050399  678.122804
#
# Region                                                                        \
# Business               B2C_1       B2C_2
# Department       Maintenance        Fees Assistance     Services        Fees
# July Income        12.401407  605.751654  347.01104   118.564711  494.416775
# July Expenditure  940.254741  130.018696  997.43726  1245.433628  405.510887
#
# Region                                                                         \
# Business                B2C_1                   B2C_2
# Department              Loans  Assistance        Fees        Fees        Fees
# July Income       1048.025689  371.021269  757.556945  649.799695  808.272143
# July Expenditure   344.450415  575.958153  568.356361  100.261720  153.546499
#
# Region                                                                         \
# Business                                                                B2C_1
# Department               Fees        Fees        Fees        Fees  Assistance
# July Income        583.868275  101.148415  633.030530  781.541381   15.169525
# July Expenditure  2758.532350  176.441238  362.752571  833.311209  375.896776
#
# Region                                                             \
# Business               B2C_2                                B2C_1
# Department              Fees        Fees        Fees        Loans
# July Income       266.454199  739.572642  355.426656  4390.034996
# July Expenditure   47.012362   25.375990    8.117733  4546.259521
#
# Region                                                                \
# Business                B2C_2                                  B2C_1
# Department               Fees  Maintenance         Fees  Maintenance
# July Income        489.394043  6676.634877  3015.688737  6492.681606
# July Expenditure  4084.867588  3945.741775   879.520815  2175.680474
#
# Region                                                              \
# Business                                        B2C_2        Fleet
# Department          Services Maintenance         Fees  Maintenance
# July Income       531.406833  115.977944   581.027946  1075.066865
# July Expenditure  774.506621  386.145803  1681.873219   907.386017
#
# Region                                                                         \
# Business               B2C_2       B2C_1       B2C_2       B2C_1        B2C_2
# Department       Maintenance Maintenance        Fees  Assistance     Services
# July Income        77.955800   36.727804   77.917076  144.783504  2402.509935
# July Expenditure  260.985607    6.297530  124.021143  537.248575  2562.432567
#
# Region                                                                \
# Business
# Department               Fees         Fees         Fees         Fees
# July Income       4819.372813  4647.619292  4361.316623  4252.457998
# July Expenditure  3759.900813  2672.913287  4424.897999  3558.504280
#
# Region                                                              \
# Business                                        B2C_1        B2C_2
# Department              Fees         Fees  Assistance         Fees
# July Income        18.062144  2563.440537  848.219246  6571.700072
# July Expenditure  492.714560  1502.913639  369.587680  1333.269281
#
# Region                                                                \
# Business
# Department               Fees         Fees         Fees         Fees
# July Income       2598.683460  4783.842684  3954.841720  3419.620971
# July Expenditure  2764.773085  1894.137608  1103.537745  5708.104438
#
# Region                                                                \
# Business                             B2C_1                       B2B
# Department               Fees   Assistance   Assistance  Maintenance
# July Income       3441.977429    94.639509  1328.369146  3372.558009
# July Expenditure  4533.430783  1226.769187  2855.535307  3920.581891
#
# Region                                                            DE  \
# Business                B2C_2        Fleet        B2C_2        B2C_1
# Department        Maintenance     Services  Maintenance        Loans
# July Income       5162.166016   944.967447  2671.321843  1020.832357
# July Expenditure  2216.411357  2283.039488  2226.771261  1528.415476
#
# Region                                                              \
# Business
# Department             Loans  Maintenance       Loans        Loans
# July Income        23.885113  3733.586813  425.116792  3738.765202
# July Expenditure  126.123202   931.514334   46.619134  1922.473025
#
# Region                                                                \
# Business                Fleet        B2C_1
# Department         Assistance        Loans        Loans        Loans
# July Income       1375.640482  4277.262593  5862.102250  2508.323769
# July Expenditure  4926.122771  3495.003287   429.139951   907.956117
#
# Region                                                               \
# Business                                                      B2C_2
# Department       Maintenance        Loans        Loans         Fees
# July Income       136.730209  5343.051080  5259.935003  2073.186893
# July Expenditure  637.118494  1129.900035   316.124280  2152.546226
#
# Region                                                                \
# Business                B2C_1                                  B2C_2
# Department              Loans        Loans        Loans        Loans
# July Income       4503.268084  3229.983631  1668.892334   521.641294
# July Expenditure  3250.427338   332.321050  4232.285829  3777.519470
#
# Region                                                             \
# Business                B2C_1
# Department              Loans       Loans       Loans       Loans
# July Income       2441.385722  113.361492   88.243087  539.145953
# July Expenditure  4820.313413  579.305139  759.314731  309.613208
#
# Region                                                                \
# Business                                            B2B        B2C_1
# Department         Assistance        Loans  Maintenance        Loans
# July Income       1483.330013  1507.661755  4634.348881   916.396488
# July Expenditure  2109.303652  2927.208518   537.493501  1993.037136
#
# Region                                                                \
# Business
# Department        Maintenance        Loans        Loans        Loans
# July Income       4402.754958  3173.464987  1951.011453   820.193401
# July Expenditure   124.384785   379.096014   643.537655  3810.692882
#
# Region                                                                \
# Business                  B2B                     B2C_1
# Department         Assistance        Loans        Loans        Loans
# July Income       2522.108760  2545.439131  1860.542199  3826.290475
# July Expenditure  4004.471442   280.058690  1795.794648  1709.116922
#
# Region                                                               \
# Business                                                      B2C_2
# Department             Loans        Loans        Loans         Fees
# July Income       937.771164  1778.634782  4512.455299  1242.296640
# July Expenditure  152.887409  2133.416364  2040.154383  1128.286525
#
# Region                                                                \
# Business                B2C_1                     B2C_2        B2C_1
# Department              Loans   Assistance         Fees        Loans
# July Income       1328.655341  1526.464356  5349.414469  3873.474013
# July Expenditure   225.832956   291.858463  1130.123698   726.161252
#
# Region                                                              \
# Business
# Department              Loans        Loans       Loans       Loans
# July Income         50.565976  1230.950206  127.421705  749.545625
# July Expenditure  1372.992080  1436.915962  707.806983  951.458605
#
# Region                                                               \
# Business
# Department       Maintenance        Loans        Loans        Loans
# July Income       821.035831  1684.463420  2190.394417  1117.594883
# July Expenditure  200.303353  1151.123843   354.128587   163.754696
#
# Region                                                               \
# Business
# Department              Loans        Loans       Loans        Loans
# July Income       5217.488433  3417.226247  572.095392  1112.273597
# July Expenditure   647.649860  1627.859796  867.275541  1678.186091
#
# Region                                                                \
# Business                             B2C_2                       B2B
# Department         Assistance         Fees     Services        Loans
# July Income       3772.771370  3338.167026   391.932438  3352.135821
# July Expenditure  1269.743173   696.858209  2246.030527  1123.637992
#
# Region                                                               \
# Business                B2C_1        B2C_2       B2C_1
# Department         Assistance         Fees       Loans        Loans
# July Income       1507.722429  3753.576951  516.035293  2833.868911
# July Expenditure  2033.416938   430.600715  442.184471  1911.459936
#
# Region                                                                \
# Business                                            B2B        B2C_1
# Department              Loans   Assistance        Loans   Assistance
# July Income       1235.827928  3695.833633  1293.005458  1045.211675
# July Expenditure   948.393978   908.020762   686.702153   778.889908
#
# Region                                                               \
# Business                B2C_2        B2C_1        B2C_2       B2C_1
# Department         Assistance        Loans         Fees  Assistance
# July Income       1193.279393  1537.788015  2696.894729  923.860485
# July Expenditure   629.650894     8.829838  3463.454641  902.583747
#
# Region                                                               \
# Business                                           B2B        B2C_1
# Department        Maintenance       Loans        Loans   Assistance
# July Income       2484.119469  531.782300   262.160580  1389.010860
# July Expenditure   412.371016  793.424378  2228.997241   923.624995
#
# Region                                                               \
# Business                             B2C_2        B2C_1
# Department              Loans         Fees        Loans       Loans
# July Income        731.129790  1434.676605  1968.928878  577.391268
# July Expenditure  1358.991312  2261.982661   122.505909  963.418452
#
# Region                                                               \
# Business                  B2B        B2C_1
# Department        Maintenance  Maintenance       Loans  Maintenance
# July Income       2589.142922  1987.297299  524.372519  1154.575672
# July Expenditure  1799.441807   561.363760  966.724721  1073.273588
#
# Region                                                                \
# Business
# Department        Maintenance  Maintenance        Loans   Assistance
# July Income       1912.878653   809.869996   551.125396  2319.068234
# July Expenditure  1614.709380  1265.167851  2249.066455   697.841681
#
# Region                                                               \
# Business                                          B2C_2       B2C_1
# Department              Loans  Maintenance        Loans Maintenance
# July Income        389.918215  1503.690999  1307.493979  573.886462
# July Expenditure  2368.576688  1522.139714  1117.147312  485.177940
#
# Region                                                               \
# Business               B2C_2          B2B        B2C_1
# Department              Fees        Loans        Loans  Maintenance
# July Income       397.582115  1561.484608  1882.024811  2393.581231
# July Expenditure  894.493128   923.533232  1859.708217  1039.358761
#
# Region                                                               \
# Business                 B2B        B2C_2
# Department       Maintenance   Assistance        Loans         Fees
# July Income       978.743596   401.870372  1967.401099   634.269243
# July Expenditure  727.650555  1771.948815  1559.302268  1471.988019
#
# Region                                                                \
# Business                B2C_1                     B2C_2        B2C_1
# Department        Maintenance   Assistance         Fees  Maintenance
# July Income       1819.477649  1809.184133  1991.890598  1513.745594
# July Expenditure  2815.274910  3133.315005  1292.849417   379.792839
#
# Region                                                              \
# Business              B2C_2          B2B        B2C_2        B2C_1
# Department             Fees   Assistance         Fees   Assistance
# July Income       284.40737  1888.462460  1513.512092  1530.250748
# July Expenditure  827.74192  1121.472313   763.804047  1286.742492
#
# Region                                                                \
# Business                                          B2C_2
# Department         Assistance        Loans         Fees         Fees
# July Income       3142.639285  2097.564191   721.601581  2142.039613
# July Expenditure   723.504990  1314.031337  1751.443371   529.974368
#
# Region                                                              \
# Business               B2C_1                    B2C_2        B2C_1
# Department        Assistance  Assistance         Fees        Loans
# July Income        76.393868  854.513085  1499.644829  1298.716928
# July Expenditure  189.383119  321.793969  1518.757662  1709.566449
#
# Region                                                                \
# Business                                            B2B        B2C_1
# Department              Loans        Loans     Services        Loans
# July Income       2805.459293  1757.898948  1723.551739  2058.796125
# July Expenditure  1117.959960   804.719558  2271.299577  1081.828174
#
# Region                                                              \
# Business                B2C_2                   B2C_1        B2C_2
# Department               Fees        Fees  Assistance         Fees
# July Income       2526.367325  307.492101  681.150130   964.693623
# July Expenditure   662.180455  167.634105    5.148202  2384.956429
#
# Region                                                                \
# Business                B2C_1                       B2B        B2C_2
# Department              Loans  Maintenance   Assistance         Fees
# July Income       2515.890933  2646.232176  2280.975232  2607.808636
# July Expenditure   412.826632   269.380007   513.991495  1257.310121
#
# Region                                                               \
# Business                B2C_1       B2C_2                     B2C_1
# Department              Loans        Fees         Fees        Loans
# July Income        398.346829  640.185515  1793.453433  2180.006567
# July Expenditure  1897.156230   36.600978   369.065313   468.482416
#
# Region                                                              \
# Business                                          B2B
# Department             Loans   Assistance       Loans  Maintenance
# July Income       476.177853  1871.955719  108.651799  2719.100688
# July Expenditure  677.907173  1168.421207  764.637856  2121.175109
#
# Region                                                                \
# Business                B2C_1          B2B        B2C_2        B2C_1
# Department              Loans        Loans        Loans   Assistance
# July Income       2482.858008  1751.054717  2113.690604  1828.060926
# July Expenditure  2541.271758  1170.504805   562.690157  3554.691866
#
# Region                                                                \
# Business                B2C_2          B2B        B2C_2
# Department               Fees  Maintenance  Maintenance         Fees
# July Income       2759.454501  1527.563627  3179.726189  1842.354757
# July Expenditure  2033.600335  1475.921313   713.891492  2938.315940
#
# Region                                                               \
# Business                B2C_1       B2C_2        B2C_1
# Department        Maintenance        Fees        Loans  Maintenance
# July Income       1150.768534  770.642573   171.745977   261.250777
# July Expenditure   429.747120  192.042331  2024.528491  4370.268956
#
# Region                                                              \
# Business               B2C_2        B2C_1
# Department              Fees  Maintenance   Assistance Maintenance
# July Income       146.950037  1234.069947   630.475116  724.914141
# July Expenditure  340.705067   918.791199  1459.682481  483.811460
#
# Region                                                               \
# Business                B2C_2       B2C_1        B2C_2        B2C_1
# Department              Loans       Loans         Fees        Loans
# July Income       2008.327789  811.138806  1263.141714  1726.297482
# July Expenditure   922.659088  705.120757   337.174497  1576.792902
#
# Region                                                                \
# Business                B2C_2        B2C_1                     Fleet
# Department               Fees        Loans   Assistance        Loans
# July Income       1804.448146  1720.405360  1958.184256  1276.242623
# July Expenditure   302.223646   659.666509   714.249265  1000.962543
#
# Region                                                               \
# Business                B2C_2                    B2C_1
# Department               Fees        Fees   Assistance   Assistance
# July Income       2435.964687  1102.54583  2628.725134  1292.872011
# July Expenditure   403.079834    88.52238   481.581900   673.041887
#
# Region                                                               \
# Business                B2C_2                                 B2C_1
# Department               Fees         Fees        Fees   Assistance
# July Income       1164.448923  1490.516254  595.881793   253.140795
# July Expenditure   139.680677   503.427697  429.399559  1735.084808
#
# Region                                                                         \
# Business                          B2C_2                       B2B       B2C_1
# Department        Maintenance      Fees         Fees        Loans Maintenance
# July Income       1709.676138  55.13845  1109.265596  1616.560761  417.434544
# July Expenditure   338.859205  44.29806   750.859397  1768.422516  388.780933
#
# Region                                                              \
# Business                            B2C_2        B2C_1
# Department       Maintenance         Fees  Maintenance Maintenance
# July Income       358.532654  2458.950252  1302.872930  253.324693
# July Expenditure   57.200285    72.907031   932.054176  777.420272
#
# Region                                                               \
# Business                  B2B        B2C_1                    B2C_2
# Department        Maintenance  Maintenance  Maintenance        Fees
# July Income       2257.017265  1274.733617  1793.876738  357.605209
# July Expenditure   642.485523  1156.131623   160.498573  162.877810
#
# Region                                                              \
# Business                            B2C_1
# Department               Fees  Assistance   Assistance Maintenance
# July Income        768.788307  757.507303    99.207907  354.300780
# July Expenditure  1111.924037  567.413988  3362.208406  711.428854
#
# Region                                                               \
# Business                B2C_2                     Fleet       B2C_2
# Department               Fees         Fees   Assistance       Loans
# July Income       1376.683670  1945.245301  1812.877261  303.237804
# July Expenditure   286.974099  1999.421544   225.511122  741.303432
#
# Region                                                               \
# Business                B2C_1
# Department              Loans       Loans   Assistance   Assistance
# July Income       3151.406064  339.660460  1805.540791  1199.360115
# July Expenditure   399.724972  979.375818  1065.071567  3233.418771
#
# Region                                                              \
# Business                B2C_2        B2C_1         B2B       B2C_1
# Department               Fees   Assistance Maintenance  Assistance
# July Income       1018.034934  1179.972207  554.413273  264.004587
# July Expenditure   852.749172   629.229602  420.587832  192.089818
#
# Region                                                               \
# Business               B2C_2        B2C_1          B2B        B2C_1
# Department              Fees   Assistance        Loans  Maintenance
# July Income       510.814728  1039.983576  1560.840151  1376.430952
# July Expenditure  971.092376   238.347969  1264.397161   145.943966
#
# Region                                                               \
# Business                B2C_2       B2C_1          B2B        B2C_2
# Department               Fees       Loans  Maintenance        Loans
# July Income       1258.168933  369.621795  1611.755841  1991.875805
# July Expenditure   459.742897  315.846256    79.880578   103.355262
#
# Region                                                               \
# Business                             B2C_1       Fleet        B2C_2
# Department               Fees   Assistance    Services         Fees
# July Income       1237.591274  1594.826025  336.206468    89.137613
# July Expenditure   812.062323  1008.799476  297.344534  1064.736526
#
# Region                                                                \
# Business                B2C_1                       B2B        B2C_2
# Department         Assistance  Maintenance  Maintenance         Fees
# July Income       1554.766844  1451.000906  1155.487460  1039.555556
# July Expenditure   889.177221   462.160657   692.749758  1016.540860
#
# Region                                                               \
# Business                              B2B        B2C_2
# Department       Maintenance  Maintenance         Fees         Fees
# July Income       557.028420   295.928233  1656.015544  1345.208549
# July Expenditure  182.253697  1910.191740   982.946841  1073.795787
#
# Region                                                              \
# Business                B2C_1          B2B       B2C_2       B2C_1
# Department        Maintenance  Maintenance        Fees Maintenance
# July Income       1066.712619  1263.572847  126.449018  407.857898
# July Expenditure   944.636290   191.596800  287.293906  910.609161
#
# Region                                                              \
# Business                            B2C_2          B2B
# Department        Maintenance        Fees  Maintenance Maintenance
# July Income       1076.350505  869.023853   914.188762  399.618671
# July Expenditure  1095.767800  989.987708  1109.425552  291.434070
#
# Region                                                              \
# Business               B2C_2
# Department              Fees         Fees        Fees         Fees
# July Income        18.218921  1322.109199  191.457591   158.286036
# July Expenditure  649.757971   357.618033  993.663541  2620.220775
#
# Region                                                              \
# Business                B2C_1       B2C_2
# Department        Maintenance        Fees         Fees        Fees
# July Income       3655.821645  453.581072  1228.963683  976.363286
# July Expenditure    33.605174  239.216534   346.364467  742.149738
#
# Region                                                                \
# Business                Fleet        B2C_2                       B2B
# Department        Maintenance         Fees         Fees  Maintenance
# July Income       2522.152944  1135.059080  1544.059946  1227.653532
# July Expenditure  2018.694225    65.395946   586.304807   275.664586
#
# Region                                                              \
# Business                B2C_2
# Department               Fees Maintenance        Fees         Fees
# July Income        236.002152  1138.40560   14.070819   919.314691
# July Expenditure  1151.479668  1305.90108  312.485757  1244.372173
#
# Region                                                                        \
# Business                                                    B2B        Fleet
# Department              Fees        Fees       Fees Maintenance        Loans
# July Income       987.425714  636.130118  35.041372  764.637756  1270.387051
# July Expenditure  204.670243  572.145356  86.956970  757.732101   358.715729
#
# Region                                                              \
# Business               B2C_2                    B2C_1
# Department       Maintenance        Fees   Assistance   Assistance
# July Income       172.671945  221.621369  2029.952054  1059.719369
# July Expenditure  436.472014  243.486036  2531.975859   838.153355
#
# Region                                                                         \
# Business               B2C_2                               B2C_1        B2C_2
# Department              Fees        Fees        Fees  Assistance         Fees
# July Income       728.720837  361.168305  844.659799  781.487605   420.547173
# July Expenditure  471.658114  662.854636  229.125106  945.128500  1193.342470
#
# Region                                                                         \
# Business               B2C_1         B2B       B2C_2
# Department        Assistance Maintenance        Fees         Fees        Fees
# July Income       265.956135  393.632126  200.600393   566.639506  520.395714
# July Expenditure  299.091472  182.794022  207.918617  3016.037804  515.221581
#
# Region                                                                         \
# Business
# Department              Fees         Fees Maintenance    Services        Fees
# July Income       922.645284  1064.367376  320.473504  499.967153  492.509524
# July Expenditure  136.375809    80.842184  390.307179  241.686914  368.859883
#
# Region                                                               \
# Business                  B2B                    B2C_2        B2C_1
# Department        Maintenance Maintenance         Fees   Assistance
# July Income       4258.464544   23.199194  1075.242509  4720.852163
# July Expenditure   597.215689  147.629108   445.551779  1863.904718
#
# Region                                                              \
# Business                  B2B       B2C_1       B2C_2
# Department        Maintenance Maintenance        Fees         Fees
# July Income        576.439415   24.636408  271.344768  1013.666986
# July Expenditure  1403.560196  432.576489  413.088480   123.272189
#
# Region                                                                         \
# Business                  B2B       B2C_1       B2C_2
# Department        Maintenance Maintenance        Fees Maintenance        Fees
# July Income        630.659808  158.404387  823.941829  165.572198  231.963374
# July Expenditure  1420.363469   97.725897  351.468142  767.794753   82.371898
#
# Region                                                                        \
# Business                            Fleet      B2C_2
# Department              Fees  Maintenance       Fees Maintenance        Fees
# July Income       602.617383    92.935561  42.325445  645.474171  885.739623
# July Expenditure  681.553671  2645.047339   2.742439  462.032016   62.200395
#
# Region                                                                        \
# Business               Fleet       B2C_2       B2C_1       B2C_2
# Department          Services        Fees  Assistance    Services        Fees
# July Income       602.890134  615.720773  760.288683  326.093279  446.361071
# ...
# Business
# Department        Maintenance        Fees Maintenance         Fees
# July Income       5239.204061  563.943502  142.300177  1062.754643
# July Expenditure   639.554067  734.788687  349.089402   418.674564
#
# Region                                                              \
# Business                             Fleet         B2B       Fleet
# Department               Fees  Maintenance Maintenance Maintenance
# July Income       1106.750381  3569.826190  255.203084  152.482754
# July Expenditure   703.047381   608.772494  603.786838   75.837556
#
# Region                                                                        \
# Business                 B2B       B2C_2
# Department       Maintenance        Fees        Fees Maintenance        Fees
# July Income        63.319410  799.805030  164.678210  671.993515  348.652942
# July Expenditure  290.720263  484.465512  206.505615   99.221063  769.864844
#
# Region                                                               \
# Business                                         B2C_1        B2C_2
# Department              Fees         Fees   Assistance         Fees
# July Income       473.095802   811.181030  2688.370114  1417.948642
# July Expenditure  319.411909  3270.669977  1664.399075  3260.566476
#
# Region                                                               \
# Business                Fleet        B2C_2        Fleet       B2C_2
# Department        Maintenance  Maintenance     Services Maintenance
# July Income       2365.276740  4274.045942  4870.746983  103.014739
# July Expenditure   399.928755  1801.155905   532.817078  264.210035
#
# Region                                 UK                                      \
# Business                            B2C_1
# Department          Services        Loans       Loans        Loans      Loans
# July Income       477.695226   247.600197  405.131193   706.570810  40.254600
# July Expenditure  192.474933  1061.483791  688.793639  1598.211584  19.318779
#
# Region                                                                         \
# Business
# Department             Loans       Loans        Loans  Assistance       Loans
# July Income       122.924111  502.993285  1275.923840  329.959341   87.127735
# July Expenditure    0.988165   16.360422  6648.353737  334.010670  166.112912
#
# Region                                                                    \
# Business                                     B2C_2      B2C_1      Fleet
# Department            Loans Maintenance       Fees      Loans Assistance
# July Income       86.035886   49.129118  25.712841  35.644878   81.03116
# July Expenditure  86.035886   49.129118  25.712841  35.644878   81.03116
#
# Region                                                                  \
# Business              B2C_1      B2C_2                B2C_1
# Department            Loans       Fees       Fees     Loans      Loans
# July Income       11.419124  62.755536  72.543955  8.923425  22.965168
# July Expenditure  11.419124  62.755536  72.543955  8.923425  22.965168
#
# Region                                                                   \
# Business                                      B2B      B2C_2      Fleet
# Department            Loans      Loans      Loans      Loans   Services
# July Income       86.654627  18.862838  52.786537  16.266026  18.712403
# July Expenditure  86.654627  18.862838  52.786537  16.266026  18.712403
#
# Region                                                                   \
# Business              B2C_2      B2C_1      B2C_2      B2C_1
# Department             Fees      Loans       Fees      Loans Assistance
# July Income       59.562225  28.306531  22.044052  67.746394    7.51423
# July Expenditure  59.562225  28.306531  22.044052  67.746394    7.51423
#
# Region                                                                    \
# Business              B2C_2       B2C_1      B2C_2      B2C_1        B2B
# Department             Fees Maintenance       Fees      Loans Assistance
# July Income       35.040262   46.226529  48.084989  73.072801  81.476909
# July Expenditure  35.040262   46.226529  48.084989  73.072801  81.476909
#
# Region                                                                   \
# Business              B2C_1        B2B      B2C_1                 B2C_2
# Department            Loans Assistance      Loans      Loans      Loans
# July Income       51.080468  63.282159  54.648819  16.698172  81.994385
# July Expenditure  51.080468  63.282159  54.648819  16.698172  81.994385
#
# Region                                                                 \
# Business              B2C_1                                     B2C_2
# Department            Loans     Loans      Loans     Loans       Fees
# July Income       38.007382  3.236147  58.833093  0.323211  25.643547
# July Expenditure  38.007382  3.236147  58.833093  0.323211  25.643547
#
# Region                                                                 \
# Business             B2C_1                           B2C_2      B2C_1
# Department           Loans      Loans     Loans       Fees      Loans
# July Income       4.130886  66.526634  84.89496  26.196712  23.193527
# July Expenditure  4.130886  66.526634  84.89496  26.196712  23.193527
#
# Region                                                                 \
# Business                B2B      B2C_1
# Department            Loans Assistance    Loans      Loans      Loans
# July Income       22.078474  53.619737  9.54231  64.833124  86.150633
# July Expenditure  22.078474  53.619737  9.54231  64.833124  86.150633
#
# Region                                                                 \
# Business
# Department            Loans     Loans Assistance     Loans Assistance
# July Income       74.959128  8.467254  29.267774  48.20149  61.441766
# July Expenditure  74.959128  8.467254  29.267774  48.20149  61.441766
#
# Region                                                                  \
# Business                        B2C_2                 B2C_1      B2C_2
# Department            Loans      Fees      Loans      Loans   Services
# July Income       48.995392  1.977576  83.804968  46.954568  36.386364
# July Expenditure  48.995392  1.977576  83.804968  46.954568  36.386364
#
# Region                                                                   \
# Business              B2C_1
# Department            Loans      Loans Assistance      Loans      Loans
# July Income       72.764704  52.731914  38.039532  49.989838  19.244496
# July Expenditure  72.764704  52.731914  38.039532  49.989838  19.244496
#
# Region                                                                    \
# Business                B2B      B2C_1
# Department            Loans      Loans Maintenance Assistance Assistance
# July Income       27.923534  16.015058   63.336042   41.46247  43.482491
# July Expenditure  27.923534  16.015058   63.336042   41.46247  43.482491
#
# Region                                                                     \
# Business                                                B2C_2       B2C_1
# Department       Maintenance Assistance      Loans       Fees Maintenance
# July Income        86.800459  65.683697  27.049999  33.173417   71.916702
# July Expenditure   86.800459  65.683697  27.049999  33.173417   71.916702
#
# Region                                                                   \
# Business                                               Fleet      B2C_1
# Department            Loans      Loans      Loans   Services      Loans
# July Income       14.405298  20.272656  17.280079  26.190209  80.576155
# July Expenditure  14.405298  20.272656  17.280079  26.190209  80.576155
#
# Region                                                                    \
# Business                                      B2B      B2C_1         B2B
# Department            Loans      Loans Assistance   Services Maintenance
# July Income       26.832396  39.408201  80.487544  78.212187   56.905378
# July Expenditure  26.832396  39.408201  80.487544  78.212187   56.905378
#
# Region                                                                  \
# Business              B2C_2                                      B2C_1
# Department         Services       Fees       Fees      Fees Assistance
# July Income       68.249411  69.875947  24.479773  27.78108  79.047499
# July Expenditure  68.249411  69.875947  24.479773  27.78108  79.047499
#
# Region                                                                     \
# Business                B2B       B2C_1                   B2B       B2C_1
# Department       Assistance Maintenance Maintenance     Loans Maintenance
# July Income        1.800817    85.60451   58.060923  83.46649   43.377639
# July Expenditure   1.800817    85.60451   58.060923  83.46649   43.377639
#
# Region                                                                     \
# Business                          Fleet       B2C_1      B2C_2
# Department       Maintenance      Loans Maintenance       Fees       Fees
# July Income        18.908362  76.840282    1.661304  25.004692  80.250224
# July Expenditure   18.908362  76.840282    1.661304  25.004692  80.250224
#
# Region                                                                     \
# Business               B2C_1                 B2C_2      Fleet       B2C_1
# Department       Maintenance Maintenance      Fees   Services Maintenance
# July Income        19.212788    32.60489  1.227968  70.973373   85.231691
# July Expenditure   19.212788    32.60489  1.227968  70.973373   85.231691
#
# Region                                                                     \
# Business              B2C_2                                         B2C_1
# Department            Loans      Loans Maintenance       Fees Maintenance
# July Income       17.705219  78.327186   27.842372  71.327145    2.371468
# July Expenditure  17.705219  78.327186   27.842372  71.327145    2.371468
#
# Region                                                                    \
# Business                                    B2C_2      B2C_1         B2B
# Department       Maintenance Assistance      Fees Assistance Maintenance
# July Income        61.382482  52.815534  7.991838  61.897334   12.017695
# July Expenditure   61.382482  52.815534  7.991838  61.897334   12.017695
#
# Region                                                                      \
# Business                          B2C_1         B2B      B2C_2       B2C_1
# Department       Maintenance Assistance Maintenance       Fees Maintenance
# July Income         4.567958  44.103642   84.320759  84.912026   69.879071
# July Expenditure    4.567958  44.103642   84.320759  84.912026   69.879071
#
# Region                                                                    \
# Business                                    B2C_2      Fleet         B2B
# Department       Maintenance Assistance      Fees   Services Maintenance
# July Income        14.575308   6.061728  28.83433  46.151674   49.280258
# July Expenditure   14.575308   6.061728  28.83433  46.151674   49.280258
#
# Region                                                                     \
# Business               B2C_2                              B2B       B2C_1
# Department       Maintenance       Fees       Fees Assistance Maintenance
# July Income         6.531136  69.194388  84.847137  22.170258    53.40346
# July Expenditure    6.531136  69.194388  84.847137  22.170258    53.40346
#
# Region                                                                     \
# Business                 B2B                 B2C_2
# Department       Maintenance   Services       Fees       Fees Maintenance
# July Income         3.900172  53.051132  64.960703  15.102461   22.028934
# July Expenditure    3.900172  53.051132  64.960703  15.102461   22.028934
#
# Region                                                                     \
# Business              B2C_1      Fleet         B2B       B2C_1
# Department            Loans   Services Maintenance Maintenance Assistance
# July Income       60.502168  28.743769   77.671165   18.252012  86.388912
# July Expenditure  60.502168  28.743769   77.671165   18.252012  86.388912
#
# Region                                                                     \
# Business                            B2B      B2C_1         B2B      B2C_2
# Department            Loans Maintenance Assistance Maintenance       Fees
# July Income       43.892414    39.77787   1.733628   15.822908  32.099675
# July Expenditure  43.892414    39.77787   1.733628   15.822908  32.099675
#
# Region                                                                    \
# Business                                       B2B      B2C_2      B2C_1
# Department             Fees       Fees Maintenance       Fees Assistance
# July Income       23.908519  46.889267   35.227196  71.724795  55.219993
# July Expenditure  23.908519  46.889267   35.227196  71.724795  55.219993
#
# Region                                                                 \
# Business              Fleet      B2C_2                          B2C_1
# Department         Services       Fees     Fees       Fees Assistance
# July Income       71.694167  73.080537  10.9892  50.142793  72.922099
# July Expenditure  71.694167  73.080537  10.9892  50.142793  72.922099
#
# Region                                                                  \
# Business              B2C_2
# Department             Fees       Fees       Fees      Fees      Loans
# July Income       43.272097  49.252748  81.848519  5.237351  21.114587
# July Expenditure  43.272097  49.252748  81.848519  5.237351  21.114587
#
# Region                                                                   \
# Business
# Department             Fees       Fees       Fees       Fees   Services
# July Income       28.045638  55.519618  41.322105  22.170975  34.456786
# July Expenditure  28.045638  55.519618  41.322105  22.170975  34.456786
#
# Region                                                                   \
# Business
# Department       Maintenance   Services       Fees  Services       Fees
# July Income        54.411047  78.792112  25.573851  2.266858  46.302823
# July Expenditure   54.411047  78.792112  25.573851  2.266858  46.302823
#
# Region                                                                   \
# Business                                               B2C_1      B2C_2
# Department             Fees   Services       Fees Assistance   Services
# July Income       44.591934  29.574544  41.775147  74.407747  81.381633
# July Expenditure  44.591934  29.574544  41.775147  74.407747  81.381633
#
# Region                                                                    \
# Business                                    B2C_1         B2B      B2C_2
# Department           Loans Maintenance Assistance Maintenance       Fees
# July Income       11.26844   27.896447  49.422454   64.677729  58.514616
# July Expenditure  11.26844   27.896447  49.422454   64.677729  58.514616
#
# Region
# Business
# Department             Fees
# July Income       25.489051
# July Expenditure  25.489051

# %%
frames = [df_t, df_next_t]
new = pd.concat([df_t, df_next_t]) # pd.concat(frames, axis=1)
print(new.shape)
new.tail()
# Out:
# /tmp/ipykernel_1069/637700131.py:2: RuntimeWarning: '<' not supported between instances of 'tuple' and 'int', sort order is undefined for incomparable objects.
#   new = pd.concat([df_t, df_next_t]) # pd.concat(frames, axis=1)
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipykernel_1069/637700131.py in <module>
#       1 frames = [df_t, df_next_t]
# ----> 2 new = pd.concat([df_t, df_next_t]) # pd.concat(frames, axis=1)
#       3 print(new.shape)
#       4 new.tail()
#
# ~/.local/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     357     )
#     358
# --> 359     return op.get_result()
#     360
#     361
#
# ~/.local/lib/python3.9/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     586                     obj_labels = obj.axes[1 - ax]
#     587                     if not new_labels.equals(obj_labels):
# --> 588                         indexers[ax] = obj_labels.get_indexer(new_labels)
#     589
#     590                 mgrs_indexers.append((obj._mgr, indexers))
#
# ~/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3719
#    3720         if not self._index_as_unique:
# -> 3721             raise InvalidIndexError(self._requires_unique_msg)
#    3722
#    3723         if len(target) == 0:
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
new.tail(12)

# %%
# re-transpose back 

df = new.T
print(df.shape)

# %%
df.head()

# %%
# reset index
df = df.reset_index()
df.head()

# %% [raw]
# Insert last month Income after previous month income

# %%
## find last month 
income_col=[]
## iterate through column indices
for col in range(0, len(df.columns)):
    if 'Income' in df.columns[col]: #  identify column index for column with Income
        income_col.append(col)
        
        
income_col

# %%
# last month
print(df.columns[max(income_col)])

# previous month
print(df.columns[income_col[-2]])

# %%
temp = df.copy()

temp.pop(temp.columns[max(income_col)]) 
temp.insert(loc=income_col[-2] + 1, # 6
            column= df.columns[max(income_col)], # July Income
            value= df.iloc[:, max(income_col)] )  # values of July
print(temp.shape)
print(temp.columns)
temp.head()

# %%
# save back to df
df = temp.copy()
df.shape

# %%
df.columns

# %%
# save_back to 'Budget_raw.xlsx'

df.to_excel('Budget_raw.xlsx', 
            sheet_name='Data',
            engine='xlsxwriter', 
            index=False) # 'Budget_raw_update.xlsx'

# %% [markdown]
# # Excel workbook

# %%
# load a specific spreadsheet
# be carefull, the excel file should be closed on your computer in order to access it

# load Budget_raw.xlsx workbook
filename = 'Budget_raw.xlsx'
wb = load_workbook(filename= filename, #relative path
                   #read_only=True, # optimised for reading, content cannot be edited
                   data_only =True) # controls whether cells with formulae have either the formula (default) or the value stored the last time Excel read the sheet

# %%
# get sheetnames of the workbook
wb.sheetnames

# %% [raw]
# Metadata

# %%
# Metadata
wb.properties

# %%
# add some metadata

wb.properties.title  = 'Budget_Processed Excel Automation'
wb.properties.creator  = 'Cristina Teleuca'
wb.properties.description  = 'Excel Manipulation with Python openpyxl' 
wb.properties.keywords  = ['Excel', 'Automation', 'Python', 'openpyxl']

wb.properties

# %% [raw]
# Worksheet

# %%
# assign sheet for sheetname 'Data' the sheet we'll work with
sheet = wb['Data']
sheet.title

# %%
# get nb of rows of a sheet
print(sheet.max_row)

# get nb of columns of a sheet
print(sheet.max_column)

# %%
# save the workbook into another excel "Budget_processed.xlsx" 
wb.save('Budget_processed.xlsx')
# check if the new excel file was created
os.listdir()

# %% [markdown]
# # Excel exploration with openpyxl

# %%
# compute the range of the whole dataframe 
max_row, max_col = df.shape
print('df shape: ', max_row, max_col) #df.shape method start at o indexing

df_range = xl_range(0, # starting row
                    0, # starting column
                    max_row, # last row index
                    max_col - 1) # last column -1 as the index starts a 0
print('in excel the df cellrange is : ', df_range)

# %%
# Access all cells from A1 to 05
for idx, row in enumerate(sheet['A1:O5']):
    print(idx+1, [x.value for x in row])

# %%
# start indices
start_point = xl_rowcol_to_cell(0,0) # coordinates of top lef of df
start_col = xl_col_to_name(0)# # get the column letter for first column
print("start point:", start_point,     
      "start col:", start_col)

# %%
# end indices
end_point = xl_rowcol_to_cell(max_row, max_col-1) # # coordinates of bottom right of df
end_col = xl_col_to_name(max_col-1) # get the column letter for the last column
end_row = max_row + 1 # last row in excel (+1)
print("end point:", end_point, 
      "end_row:", end_row,      
      "end col:", end_col)

# %%
# get the index nb of column O
column_index_from_string('O')

# %%
# reverse
get_column_letter(15)

# %%
# read all values from 1st row
print('nb of rows: ' , sheet.max_row)
print('nb of columns: ' , sheet.max_column)

# iterate the 1 row values of the sheet
for i in range(1, sheet.max_column+1): # add + 1, as the range function 2nd argument is not inclusive
    ref = sheet.cell(row=1, column=i)
    print(ref.column, ref.value)

# %%
# iterate the 1 Column values of the sheet of the sheet up tp 10th row
for i in range(1, 10 + 1): # add + 1, as the range function 2nd argument is not inclusive
    ref = sheet.cell(row=i, column=1)
    print(ref.column, ref.value)

# %%
# iterate the 2nd Column values of the sheet of the sheet up tp 10th row
for i in range(1, 10 + 1): # add + 1, as the range function 2nd argument is not inclusive
    ref = sheet.cell(row=i, column=2)
    print(ref.column, ref.value)

# %%
# iterate the last_column values of the sheet up tp 10th row
last_column = sheet.max_column

for i in range(1, 10 + 1): # add + 1, as the range function 2nd argument is not inclusive
    ref = sheet.cell(row=i, column=last_column)
    print(ref.column, ref.value)

# %% [markdown]
# # Add columns

# %% [markdown]
# ## Income

# %% [markdown]
# Total Income

# %% [raw]
# We want to add a column that will sum up all income columns from Jan to June
# # 1. Identify columns that have the string Income in it
# # 2. Sum up Income columns row by row
# # 3. order columns

# %%
# how to find a substring in a string

fullstring = "StackAbuse"
substring = "tack"

if substring in fullstring:
    print("Found!")
else:
    print("Not found!")

# %%
# 1. Identify columns that have the string Income in it

## create an empty lis where we'll store column names that heve the string "Income" in it
income_col=[]
## iterate through column indices
for col in range(0, len(df.columns)):
    if 'Income' in df.columns[col]: #  identify column index for column with Income
        income_col.append(col) # if column is identify store its index in the income_col list

print(income_col) # the list with column indices that have Income in columns

# assign variables with the start column index and the end column index
income_start= income_col[0]
income_end= income_col[-1]
print(income_start, income_end)

# %%
# check those columns at found indices 
df.iloc[:, income_start:income_end+1] # equal to df.iloc[all rows, from col 3 to col 9]

# %%
# 2.compute the total income and assign it in a new column in the df
# and add a new column 'Total Income' that will store the some of columns

df['Total Income'] = df.iloc[:, income_start:income_end].sum(axis=1) # axis=1 is  the column axis
df.head() #the column was added at the the end

# %%
income_end

# %%
# order: we want to order columns so Total Income would follof the Income columns
# cut and insert the column after all Income months columns

df.insert(income_end + 1, # at what index to insesrt
          'Total Income', # Label of the inserted column.
          df.pop('Total Income')) # Return item and drop from frame
df.head()

# %% [raw]
# Let's have look where Income stands in the excel

# %%
# find column number of column Jan Income in Excel
for i in range(1, sheet.max_column+1):# without + 1
    ref = sheet.cell(row=1, column=i)
    if ref.value == 'Jan Income':
        print('in EXCEL the column nb for Jan Income is: ', ref.column)

# %%
# find column number that have Income months

income_col = []
for i in range(1, sheet.max_column+1):# without + 1
    ref = sheet.cell(row=1, column=i)
    if 'Income' in ref.value:
        income_col.append(ref.column)

print(income_col)

# %%
income_start= income_col[0] - 1
print(income_start)
income_end= income_col[-1] -1 
print(income_end)
print('')

# find the letters corespondin to this columns
print('income starts at column: ', xl_col_to_name(income_start),
      'income end at column: ', xl_col_to_name(income_end))

# %%
income_col

# %%
# compute where to copy/past the total for expenditure
total_inc_col = income_col[-1] + 1
# we would like to insert the column Total Income at column 10
print(total_inc_col)

# %%
# insert columns
sheet.insert_cols(idx= total_inc_col, # column location
                  amount=1) # how many columns to insert


wb.save('Budget_processed.xlsx')

# %%
# in updated excel, we inserted an empty column (after June Income)

for idx, row in enumerate(sheet['A1:L5']):
    print(idx+1, [x.value for x in row])

# %%
# save the column 'Total Income' from df computed with pandas in list cellrange

cellrange = df['Total Income']

# the column index (in excel) where we want to write
print(total_inc_col)

# starting row 2
row= 2

# copy the elements from cellrange in excel
for i in range(0, len(cellrange)):
    sheet.cell(row=row, column = total_inc_col).value= cellrange[i]
    row=row+1

# save the modifications
wb.save('Budget_processed.xlsx')

# %%
print(total_inc_col)
# in updated excel, we wrote the cellrange datas in the column 10

for idx, row in enumerate(sheet['A1:L5']):
    print(idx+1, [x.value for x in row])

# %%
# write column name for Total expenditure as a header
# compute this location...
total_inc_col_letter = get_column_letter(total_inc_col)
total_inc_row = 1
total_inc_cel_ref = str(total_inc_col_letter) + str(total_inc_row)
total_inc_cel_ref

# %%
# write it in excel 
sheet[total_inc_cel_ref]= 'Total Income'
wb.save('Budget_processed.xlsx') 

for idx, row in enumerate(sheet['A1:L3']):
    print(idx+1, [x.value for x in row])

# %%
# display image
img = mpimg.imread('images/img_1.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %% [markdown]
# ## Expenditure

# %% [markdown]
# Total Expenditure

# %%
# first compute total income for all months in df

# identify column index for column with Income
expenditure_col=[]
for col in range(0, len(df.columns)):
    if 'Expenditure' in df.columns[col]:
        expenditure_col.append(col)

print(expenditure_col)

expenditure_start= expenditure_col[0]
expenditure_end= expenditure_col[-1]

# %%
#check those columns at found indices 
df.iloc[:, expenditure_start:expenditure_end+1]

# %%
# compute the total income and assign it in a new column in the df
df['Total Expenditure'] = df.iloc[:, expenditure_start:expenditure_end].sum(axis=1)
df.head() #the column was added at the the end

# %%
# find column number of column Jan Income
for i in range(1, sheet.max_column+1):# without + 1
    ref = sheet.cell(row=1, column=i)
    if ref.value == 'Jan Expenditure':
        print('the column nb for Jan Expenditure is: ', ref.column)

# %%
# find column number that have Income months

expenditure_col = []
for i in range(1, sheet.max_column+1):# without + 1
    ref = sheet.cell(row=1, column=i)
    if 'Expenditure' in ref.value:
        expenditure_col.append(ref.column)

print(expenditure_col)

# %%
expenditure_start= expenditure_col[0] - 1
expenditure_end= expenditure_col[-1] -1 

print('expenditure starts at column: ', xl_col_to_name(expenditure_start),
      'expenditure end at column: ', xl_col_to_name(expenditure_end))

# %%
# display image
img = mpimg.imread('images/img_1.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %%
# compute where to copy/past the total for expenditure
total_exp_col = expenditure_col[-1] + 1
total_exp_col

# %%
cellrange = df['Total Expenditure']
row= 2
for i in range(0, len(cellrange)):
    sheet.cell(row=row, column = total_exp_col).value= cellrange[i]
    row=row+1

wb.save('Budget_processed.xlsx')

# %%
# write column name for Total expenditure
total_exp_col_letter = get_column_letter(total_exp_col)
total_exp_row = 1
total_exp_cel_ref = str(total_exp_col_letter) + str(total_exp_row)
total_exp_cel_ref

# %%
sheet[total_exp_cel_ref]= 'Total Expenditure'
wb.save('Budget_processed.xlsx')

# %%
for idx, row in enumerate(sheet['H1:Q5']):
    print(idx+1, [x.value for x in row])

# %%
# display image
img = mpimg.imread('images/img_2.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %% [markdown]
# # Net

# %% [raw]
# We would like to add a new column "Net" at the end of the columns
# that would soubstract Total Exp from Total Exp

# %%
df.head()

# %%
# compute Net column in df
df['Net']= df['Total Income'] - df['Total Expenditure']
df.head()

# %%
# take values for column Net from df
# and put them into a list cellrange

cellrange = list(df['Net'])
cellrange[:10]

# %%
# insert 'Net' iat index 0 (1st position)
cellrange.insert(0, 'Net')
cellrange[:10]

# %%
# column where to paste Net column
net_col = df.shape[1]
print(net_col)

# %%
print(net_col)

# from row 1
row= 1
# write  cellrange in excel at column net_col

for i in range(0, len(cellrange)):
    sheet.cell(row=row, column = net_col).value= cellrange[i]
    row=row+1

# save
wb.save('Budget_processed.xlsx')

# %%
# display image
img = mpimg.imread('images/img_3.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %%
'''
writer.save()
workbook.close()

'''

# %% [markdown]
# # Overview

# %% [raw]
# Now we'd like to work on the overview part

# %%
# overview part
img = mpimg.imread('images/img_4.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %% [raw]
# First, we'll create a new sheet "OVerview" where we'll work on Overview part data

# %%
# create sheet 'Overview'
wb.create_sheet(title='Overview')

overview= wb['Overview'] # create reference to the sheet# delete a sheet

# check the workbook sheet
print(wb.sheetnames)

# save the new workbook 
wb.save('Budget_processed.xlsx')

# %% [markdown]
# ## Income & Expenditure names & Months

# %% [raw]
# Months

# %% [raw]
# Get all the months present in the excel

# %%
# identify column index for column with Income
months=[]
for month in df.columns:
    if 'Income' in month:
        months.append(month)
print(months)

# %% [raw]
# # remove 'Total Income' from the list
# months.remove('Total Income')
# months

# %%
# remove the substring ' Income' from the list items

months = list(map(lambda x: x.replace(' Income',''), months))
print('nb of months: ', len(months))

# save in variable nb_months the nb of monthe
nb_months = len(months)

print('')
print('will have the same months for INcome, and Expenditure as well')
months

# %% [raw]
# Income

# %%
# create a list where the string "INCOME" will be repeated 7 times
# we multiply ['INCOME'] by the length of months (here 7) 

list_income= ['INCOME']* (nb_months)
list_income

# %%
# we'll do a nested list "list_inc_2" that will contain both lists:
# list_income AND months

list_inc_2 = [list_income, months]
print(list_inc_2)

# %% [raw]
# Expenditure

# %% [raw]
# Let's do the same for Expenditure..

# %%
list_expenditure= ['Expenditure']*(nb_months)
list_exp_2 = [list_expenditure, months]
print(list_exp_2)

# %% [raw]
# zip() function

# %% [raw]
# The zip() function takes iterables (can be zero or more), aggregates them in a tuple, and returns it. (it's like combining items from both lists)

# %%
languages = ['Java', 'Python']
versions = [14, 3]

result = zip(languages, versions)
print(list(result))

# %%
list(zip(list_inc_2, list_exp_2))

# %%
# let's do the same with list_inc_2, list_exp_2
# but will modify a little bit, so in final we'll have lists and not tuples
# and also we will flatten/ merge to obtain a single list by tuple
# finally we will obtain a nested list inc_exp

inc_exp = [a + b for a, b in zip(list_inc_2, list_exp_2)]
inc_exp

# %% [raw]
# Add the Inc, Exp names rows and months rows to overview

# %%
# compute dimensions of the nested list

print(inc_exp)
# how many itmes in nested list
maxr = len(inc_exp)

# how many subitmes in nested list
maxc = len(inc_exp[0])

print('')
print(maxr , maxc)

# %%
# copy to excel
for this_row in range (1, maxr + 1):
    for this_column in range (1, maxc + 1):
        #print(this_row)
       # print(this_column)
        cellsource = inc_exp[this_row-1][this_column-1]        
        overview.cell(row = this_row+1, column = this_column+1).value = cellsource 
        # !!!! (should be 10)

# see what was written
for idx,row in enumerate(overview["A1:O3"]):
    print (idx+1, [x.value for x in row])

# %%
# we have added first to rows  of the Overview part
# row nb 2, col B

img = mpimg.imread('images/img_5.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %%
# save the new workbook 
wb.save('Budget_processed.xlsx')

# %% [markdown]
# ## Monthly totals by business

# %%
# compute... :

# Groupby by Business category (yellow part)
# Monthly Total (red part)
# monthly evolution (blue part)

# %%
# total by busines type, split afterwards by INCOME and EXP

img = mpimg.imread('images/img_6.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %% [raw]
# Total by busines

# %% [raw]
# Income

# %%
# identify column index for column with Income
income_months=[]
for month in df.columns:
    if 'Income' in month:
        income_months.append(month)
        
# remove 'Total Income' from the list
income_months.remove('Total Income')
print(income_months)

# %%
# comute totals by business group for income

# first create a df= business_income where it will group by business for each month
business_income = round(df.groupby(['Business'])[income_months].sum(), 2)
business_income

# %%
# add a columns where total for all months for income will be comutes
business_income['Total Income'] = round(business_income.sum(axis=1), 2)
business_income

# %% [raw]
# Expenditure

# %%
# identify column index for column with Income
exp_months=[]
for month in df.columns:
    if 'Expenditure' in month:
        exp_months.append(month)
        
# remove 'Total Income' from the list
exp_months.remove('Total Expenditure')
print(exp_months)

# %%
business_exp = round(df.groupby(['Business'])[exp_months].sum(), 2)
business_exp['Total Expenditure'] = round(business_exp.sum(axis=1), 2)
business_exp

# %%
# join the 2 df horizontally
business_df = pd.concat([business_income, business_exp], axis=1)
business_df

# %%
# we groupby by busines (the yellow part)
# review scrrenshot !!!!
img = mpimg.imread('images/img_6.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %% [raw]
# Get the totals by columns of business_df

# %%
business_col = business_df.columns.to_list()
#business_col.remove('Total Income')
#business_col.remove('Total Expenditure')
business_col

# %%
# get Total by Month (in column)

monthly_total = round(business_df[business_col].sum(), 2)
print(len(monthly_total))
monthly_total

# %%
# total by columns for business_df (the red part)
# review screenshot !!!

img = mpimg.imread('images/img_6.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %%
ev = round(monthly_total.pct_change(), 5)
ev['Total Income'] = None
ev['Jan Expenditure'] = None
ev['Total Expenditure'] = None
ev

# %%
# evolution from month to month, that afterwords will be formated as a %
# the blue part

# review screenshot !!!
img = mpimg.imread('images/img_6.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %%
# Till now we computed:

# business_df
print(business_df.shape, business_df.iloc[:, :5])
print('')

# monthly_total
print(len(monthly_total), monthly_total[:5])
print('')

# monthly evolution
print(len(ev), ev[:5])

# %% [raw]
# We would like to write them all in our excel, sheet overview

# %%
# in our excel in the sheet Overview we have

img = mpimg.imread('images/img_5.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %% [markdown]
# ### Copy new data to excel overview

# %%
def copyRange(startCol, startRow, endCol, endRow, sheet):
    rangeSelected = []
    # Loops through selected Rows
    for i in range(
      startRow,endRow + 1,1):
        # Appends the row to a RowSelected list
        rowSelected = []
        for j in range(startCol,endCol+1,1):
            rowSelected.append(sheet.cell(row = i, column = j).value)
        # Adds the RowSelected List and nests inside the rangeSelected
        rangeSelected.append(rowSelected)

    return rangeSelected

# %%
# Paste data from copyRange into template sheet
def pasteRange(startCol, startRow, endCol, endRow, sheetReceiving, copiedData):
    countRow = 0
    for i in range(startRow,endRow+1,1):
        countCol = 0
        for j in range(startCol,endCol+1,1):
            
            sheetReceiving.cell(row = i, column = j).value = copiedData[countRow][countCol]
            countCol += 1
        countRow += 1

# %% [raw]
# cell notation with xl_rowcol_to_cell
#
# (0, 0)      # Row-column notation.
# ('A1')      # The same cell in A1 notation.
#
# (6, 2)      # Row-column notation.
# ('C7')      # The same cell in A1 notation

# %%
# cell notation with xl_rowcol_to_cell

print(xl_rowcol_to_cell(6,2)) # always add + 1
print(xl_rowcol_to_cell(0,0))
print(xl_rowcol_to_cell(9,3))

# %%
print(business_df.shape)

# get only the values of the business_df (omit indices)
business_values = business_df.values
print(len(business_values))
print(len(business_values[0]))

# %% [raw]
# We want to paste in the excel, sheet overview with function
# pasteRange()
#
# But first, we need to compute the range where to pasted

# %%
# write a function that will compute the accurate nb of rows by omitting blanks
def get_maximum_rows_blank(*, sheet_object):
    rows = 0
    for max_row, row in enumerate(sheet_object, 1):
        if  not all(col.value is None for col in row):
            rows += 1
        
    return rows

# call the new function
get_maximum_rows_blank(sheet_object = overview)

# %%
# write a function that will compute the accurate nb of rows including the blanks, up to the last non blanks
def get_maximum_rows(*, sheet_object):
    df_range= 'A1:' + str(get_column_letter(sheet_object.max_column)) + str(sheet_object.max_row)
    rows = 0
    for idx, row in enumerate(sheet_object[df_range]): # values_only=True meanse we want to access the values
        if not all(col.value is None for col in row):
            rows += 1
            last_row = idx+1
    return last_row

get_maximum_rows(sheet_object = overview)

# %%
def get_maximum_cols(sheet):
    for i in range(2, 20000):
        if sheet.cell(row=1, column= i).value == None:
            max_col = i
            break
    return max_col-1

# %%
# so will use the last non blank row with funct get_maximum_rows, which give us 3
# we know that we want to add business_df values under this row

img = mpimg.imread('images/img_5.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %%
# compute the coordianted for the range where to paste

start_row = get_maximum_rows(sheet_object = overview)
print(start_row)
start_col = 1
print(start_col)
end_row = get_maximum_rows(sheet_object = overview) + business_df.shape[0] -1
print(end_row)
end_col = business_df.shape[1] 
print(end_col)

# %%
# the range where we want to paste the data B4:O7

# check if we computed correctly the range whe we want to paste business_df values
xl_range(start_row , # starting row # 4
         start_col, # start_col B
         end_row , # end_row 0
         end_col) # end_col

# %%
# be carefull the paste range has to have the same dimensions as the selected range

pasteRange(startCol = start_col+1,
           startRow = start_row + 1, 
           endCol= end_col+1, 
           endRow = end_row +1, 
           sheetReceiving= overview,
           copiedData = business_values)

# %%
# save the new workbook 
wb.save('Budget_processed.xlsx')

# %% [raw]
# Insert Monthly total row

# %%
# insert 2 rowsat row 4 (after row INCOME/EXPEND and row with month)

overview.insert_rows(idx=4, # row location
                  amount=2) # how many rows to insert
wb.save('Budget_processed.xlsx')

# %%
# see what was written
for idx,row in enumerate(overview["A1:O7"]):
    print (idx+1, [x.value for x in row])

# %% [raw]
# Write monthly_total in excel

# %%
# copy monthly total row at 4th row

cellrange= monthly_total 
target_row= 4
for i in range(0, len(cellrange)): 
    overview.cell(row=target_row, column = i+2).value= cellrange[i]
    # + 1 because we have data shifted by 1 column in excel

# see what was written
for idx,row in enumerate(overview["A1:O7"]):
    print (idx+1, [x.value for x in row])    

wb.save('Budget_processed.xlsx')

# %% [markdown]
# Insert monthly evolution

# %% [raw]
# Evolution

# %%
# copy monthly evolution total row at 4th row

cellrange= ev
target_row= 5
for i in range(0, len(cellrange)): 
    overview.cell(row=target_row, column = i+2).value= cellrange[i]
    # + 2 because we have data shifted by 1 column in excel

# see what was written
for idx,row in enumerate(overview["A1:O7"]):
    print (idx+1, [x.value for x in row])
    
wb.save('Budget_processed.xlsx')

# %% [raw]
# Add list :
# [ Month, MonthlyTotal, M2M evol,
#   B2B, B2C_1, B2C_2, Fleet]
#
# in the 1st column ['A4:A10]

# %%
# to obtain this list...
# we neetd to contatenate the strings Month, MonthlyTotal, M2M evol
# B2B, B2C_1, B2C_2, Fleet from business_df

l1 = ['Month', 'MonthlyTotal', 'M2M evol']
l2 = list(business_df.index)
col_1 = l1 + l2
col_1

# %%
# write it to the excel

starting_row = 3

for r in col_1:
    overview.cell(row=starting_row, column=1).value = r
    # 3.3 increment the counter
    starting_row= starting_row + 1
    
# see what was written
for idx,row in enumerate(overview["A1:O7"]):
    print (idx+1, [x.value for x in row])

# !!!! Don't forget to save the modification
wb.save('Budget_processed.xlsx')

# %%
# review screenshot !!
img = mpimg.imread('images/img_7.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %% [markdown]
# ## Previous Month

# %%
# Previous month lime color
# review screenshot !!
img = mpimg.imread('images/img_6.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %%
print(months)
previous_month = months[-3]
previous_month
#months.index(previous_month)

# %%
business_df.columns

# %%
# compute the range uptil the previous month for INCOME

inc_idx= []
range_end = []

# in the incomu columns
for idx, col in enumerate(business_df.columns):
    if 'Income' in col:
        inc_idx.append(idx)
        if previous_month in col:
              range_end= idx 
                
print(min(inc_idx)) 
print(range_end)

range_prev_inc = [min(inc_idx), range_end]
print(range_prev_inc) # uptil May

# %%
# what we get up to May
business_df.iloc[:, min(inc_idx):range_end+1] # +1 as in range the interval is open

# %%
# first sum all columns
# 2nd sum all rows

previous_income = business_df.iloc[:, min(inc_idx):range_end+1].sum(axis=1).sum()
previous_income

# %%
# copy the value in excel
# first we need to identify the coordinates where to copy the valye
# we know that this cell will be above Total Columns

# %%
# columns nb where we have totals

total_col = []
# find column number of column that = Total
for i in range(1, overview.max_column+1):# without + 1
    ref = overview.cell(row=3, column=i)
    if ref.value == 'Total':
        total_col.append(ref.column)
        print('the column nb for Total is: ', ref.column)
        
print(total_col)

# %%
print('the column where to add Previous Total for INCOME', get_column_letter(total_col[0]))
row = 1 # row nb where to paste previous income value
ref = str(get_column_letter(total_col[0])) + str(row)


print('the cell reference where to add Previous Total for INCOME', ref)

# %%
# write it in Excel 
overview[ref] = round(previous_income,2)
overview[ref].value

# %%
# string Prevous month
ref = str(get_column_letter(total_col[0]-1)) + str(row)
print(ref)
overview[ref] = 'Prior'
overview[ref].value

# %%
# see what was written
for idx,row in enumerate(overview["A1:O2"]):
    print (idx+1, [x.value for x in row])

# %%
# save 
wb.save('Budget_processed.xlsx')

# %% [raw]
# now the same for expenditure previous month

# %%
# string Prevous month
ref = str(get_column_letter(total_col[1]-1)) + str(row)
ref
#overview[ref] = 'Prior'

# %%
# compute the range uptil the previous month for expenditure

inc_idx= []
range_end = []

# in the exp columns
for idx, col in enumerate(business_df.columns):
    if 'Expenditure' in col:
        inc_idx.append(idx)
        if previous_month in col:
              range_end= idx 
                
range_prev_exp = [min(inc_idx), range_end]

# compute all prior exp
previous_exp = business_df.iloc[:, min(inc_idx):range_end+1].sum(axis=1).sum()

# cell ref
row = 1 # row nb where to paste previous income value
ref = str(get_column_letter(total_col[1])) + str(row)

# write it in Excel value
overview[ref] = round(previous_exp,2)


# string Prevous month
ref = str(get_column_letter(total_col[1]-1)) + str(row)
overview[ref] = 'Prior'

# %%
# see what was written
for idx,row in enumerate(overview["A1:O2"]):
    print (idx+1, [x.value for x in row])

# %%
wb.save('Budget_processed.xlsx')

# %%
# Previous month 
# review screenshot !!
img = mpimg.imread('images/img_8.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %% [markdown]
# ## Copy / Insert/ Paste overview

# %%
# we want to insert the data frame from overview sheet to Data sheet

# Steps
# Insert rows on Data sheet
# Copy celrange from overview sheet
# Paste copied cellrane to Datasheeet
# delete overview sheet that we wont need anymore

# %%
# back to our sheet called Data
sheet.title

# %%
# insert 12 rows, starting at row 1

# insert rows

sheet.insert_rows(idx=1, # row location
                  amount=12) # how many rows to insert
wb.save('Budget_processed.xlsx')

# %%
# inserted rows in Data sheet

img = mpimg.imread('images/img_9.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %%
# copy the overview df

selectedRange = copyRange(startCol =1,
                          startRow= 1,
                          endCol= business_df.shape[1]+1 ,
                          endRow = get_maximum_rows_blank(sheet_object = overview),
                          sheet = overview)

print(len(selectedRange))
for row in selectedRange:
    print(row)

# %%
pasteRange(startCol = 1,
           startRow = 2, 
           endCol= business_df.shape[1]+1, 
           endRow = get_maximum_rows_blank(sheet_object = overview),
           sheetReceiving= sheet,
           copiedData = selectedRange)

# see what was written
for idx,row in enumerate(overview["A1:O14"]):
    print (idx+1, [x.value for x in row])

# %%
# past rows in Data sheet

img = mpimg.imread('images/img_10.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %%
wb.save('Budget_processed.xlsx')

# %%
# remove autofilers

sheet.auto_filter.ref = None
for i in range(2, sheet.max_row + 1):
    sheet.row_dimensions[i].hidden = False

wb.save('Budget_processed.xlsx')

# %%
# after removing the autofilers

img = mpimg.imread('images/img_11.PNG')
plt.imshow(img)
plt.rcParams['figure.figsize'] = [12, 10]
plt.axis('off')
plt.show()

# %%
# remove overview sheet
wb.remove(overview) 

# remove 'Department' sheet
wb.remove(wb[wb.sheetnames[1]]) 

print(wb.sheetnames)


# save the new workbook 
wb.save('Budget_processed.xlsx')

# %%
# close  workbokk
wb.close()
